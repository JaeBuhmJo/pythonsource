# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["font.family"] = "Malgun Gothic"
plt.rcParams["axes.unicode_minus"] = False

# %% [markdown]
# ### 1) 막대차트(기본)

# %%
labels = ["강백호","서태웅","정대만"]
values = [175,187,184]

plt.ylim(175,190)
g = plt.bar(labels,values, color="r")

# %% [markdown]
# ><b>색상</b>

# %% [markdown]
# ><b>축 레이블 조정</b>

# %%
plt.xticks(rotation=45)
plt.yticks(rotation=45)
g = plt.bar(labels,values, width=0.5)

# %% [markdown]
# ><b>막대 너비 조정</b>

# %%
# x축 강백호, 서태웅, 정대만 ==> 임의의 레이블 지정
xticks = ["1번학생","2번학생","3번학생"]
g = plt.bar(labels,values,width=0.5)
plt.xticks(labels,xticks)
# Out:
# ([<matplotlib.axis.XTick at 0x1d8073a8a50>,
#   <matplotlib.axis.XTick at 0x1d807355490>,
#   <matplotlib.axis.XTick at 0x1d80707b310>],
#  [Text(0.0, 0, '1번학생'), Text(1.0, 0, '2번학생'), Text(2.0, 0, '3번학생')])

# %% [markdown]
# ><b>축 레이블 rotation 설정</b>

# %% [markdown]
# ><b>막대 </b>

# %% [markdown]
# ### 2) 막대차트(심화)

# %% [markdown]
# **수평막대**

# %%
g = plt.barh(labels,values)

# %% [markdown]
# **막대 패턴**(https://matplotlib.org/stable/gallery/shapes_and_collections/hatch_style_reference.html)

# %%
g = plt.barh(labels,values)
g[0].set_hatch("/")
g[1].set_hatch("x")
g[2].set_hatch("o")

# %%
g = plt.bar(labels,values)

for idx, b in enumerate(g):
    plt.text(idx,b.get_height()+0.5, values[idx],ha="center")
