# %%
# 크롤링 라이브러리
# requests, Beautiful Soup, Selenium, scrapy,...

# 파이썬 라이브러리 사용할 수도 있으나 외부 라이브러리를 주로 사용함

# requests : 특정 url에서 정보를 가져오기 쉽게 도와주는 라이브러리

# %%
import requests
urls=["https://www.python.org/","https://www.naver.com/"]
name = "robots.txt"
for url in urls:
    print(url+name)
    robots = requests.get(url+name)
    print(robots.text)
# Out:
# https://www.python.org/robots.txt
# # Directions for robots.  See this URL:
# # http://www.robotstxt.org/robotstxt.html
# # for a description of the file format.
#
# User-agent: HTTrack
# User-agent: puf
# User-agent: MSIECrawler
# Disallow: /
#
# # The Krugle web crawler (though based on Nutch) is OK.
# User-agent: Krugle
# Allow: /
# Disallow: /~guido/orlijn/
# Disallow: /webstats/
#
# # No one should be crawling us with Nutch.
# User-agent: Nutch
# Disallow: /
#
# # Hide old versions of the documentation and various large sets of files.
# User-agent: *
# Disallow: /~guido/orlijn/
# Disallow: /webstats/
#
# https://www.naver.com/robots.txt
# User-agent: *
# Disallow: /
# Allow : /$

# %%
import urllib.request as req

url = "https://google.com"

save_file = "./google.html"

try:
    file1, header1 = req.urlretrieve(url, save_file)
except Exception as e:
    print(e)
else:
    print(header1)
    print(file1)
    print("성공")
# Out:
# Date: Thu, 06 Jul 2023 07:18:19 GMT
# Expires: -1
# Cache-Control: private, max-age=0
# Content-Type: text/html; charset=ISO-8859-1
# Content-Security-Policy-Report-Only: object-src 'none';base-uri 'self';script-src 'nonce-KVa3wXRsAmWWi0j3S7DMqg' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other-hp
# P3P: CP="This is not a P3P policy! See g.co/p3phelp for more info."
# Server: gws
# X-XSS-Protection: 0
# X-Frame-Options: SAMEORIGIN
# Set-Cookie: 1P_JAR=2023-07-06-07; expires=Sat, 05-Aug-2023 07:18:19 GMT; path=/; domain=.google.com; Secure
# Set-Cookie: AEC=Ad49MVGhS8hnWjTgE04vxzufHXtIYbmto3JB4NaQGVUVxvdiEAN8epIivyg; expires=Tue, 02-Jan-2024 07:18:19 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax
# Set-Cookie: NID=511=ccbi2aUCS66OjPAp-L9FS5CsfwvjHq1cwAJUisFJoq5NhiKJyhN0Y2jVyst2QK6bKotCdbjl18caYzgK6A9_tpnyiNbc1-jpdN0fnJrngBc_P13nOc2JsH0AuT7IRxoqdbHBIz4-HSRps_y7peTyBqsymkN51QOHYO5Fdq-hTHY; expires=Fri, 05-Jan-2024 07:18:18 GMT; path=/; domain=.google.com; HttpOnly
# Alt-Svc: h3=":443"; ma=2592000,h3-29=":443"; ma=2592000
# Accept-Ranges: none
# Vary: Accept-Encoding
# Connection: close
# Transfer-Encoding: chunked
#
#
# ./google.html
# 성공

# %% [markdown]
# ##### urlretrieve
#     - 요청하는 url의 정보를 로컬 파일로 저장
#     - 튜플로 반환됨
#     - csv, api 데이터 등 많은 양의 데이터를 한 번에 저장할 때 사용

# %%
img_url = "https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzA2MDhfNjgg%2FMDAxNjg2MjA4MDUxNzcz.0LRu-ZEx7KhZqGUGlQzfTOB3gLa1Umikb_ODWH_3Alwg.kY5hTeUSVN59Xc0KCGLjUjTZl4kZooHrws3UYE3TTv4g.JPEG.24sooamc2019%2FGettyImages-1495553264.jpg&type=a340"
html_url = "https://www.naver.com"

# 경로
img_path = "./cat.jpg"
html_path = "./naver.html"

try:
    file1, header1 = req.urlretrieve(img_url, img_path)
    file2, header2 = req.urlretrieve(html_url, html_path)
except Exception as e:
    print(e)
else:
    print("file1 {}".format(file1))
    print("file2 {}".format(file2))
# Out:
# file1 ./cat.jpg
# file2 ./naver.html

# %% [markdown]
# ##### 다운로드는 필요없고 내용만 분석하고 싶을 때
#     - open(), read()

# %%
weather_url = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=108"

data = req.urlopen(weather_url).read()
text = data.decode("utf-8")
print(text)
# Out:
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2023년 07월 06일 (목)요일 06:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2023년 07월 06일 (목)요일 06:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# 	<header>
# 		<title>전국 육상중기예보</title>
# 		<tm>202307060600</tm>
# 		<wf><![CDATA[○ (강수) 이번 예보기간 동안 전국 대부분 지방에 소나기가 오는 곳이 많겠고, 9일(일)~10일(월) 제주도에, 15일(토) 수도권과 강원영서에 흐리고 비가 오겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 22~25도, 낮 기온은 27~33도로 평년(최저기온 20~23도, 최고기온 26~30도)과 비슷하거나 조금 높겠습니다.<br />○ (주말전망) 8일(토)은 충청권과 남부지방, 제주도에 비가 오겠고, 9일(일)은 중부지방(강원영동 제외)과 전라권, 경북권에 소나기가, 제주도에는 비가 오는 곳이 있겠습니다. <br />              아침 기온은 19~25도, 낮 기온은 25~32도가 되겠습니다.<br /><br />* 우리나라 주변 기압계 변화에 따라 날씨 변동성이 큰 가운데, 비나 소나기가 내리는 지역과 시점이 변경될 가능성이 있겠으니 앞으로 발표되는 예보와 기상정보를 참고하기 바랍니다.]]></wf>
# 	</header>
# 	<body>
#
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>서울</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>인천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>수원</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>파주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>이천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>서울ㆍ인천ㆍ경기도</province>
# 				<city>평택</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>강원도영서</province>
# 				<city>춘천</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>강원도영서</province>
# 				<city>원주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>강원도영동</province>
# 				<city>강릉</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>대전ㆍ세종ㆍ충청남도</province>
# 				<city>대전</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대전ㆍ세종ㆍ충청남도</province>
# 				<city>세종</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대전ㆍ세종ㆍ충청남도</province>
# 				<city>홍성</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>충청북도</province>
# 				<city>청주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>충청북도</province>
# 				<city>충주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>충청북도</province>
# 				<city>영동</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>70</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>광주ㆍ전라남도</province>
# 				<city>광주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>광주ㆍ전라남도</province>
# 				<city>목포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>광주ㆍ전라남도</province>
# 				<city>여수</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>90</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# ...
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>포항</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>32</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>32</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>29</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>경주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>32</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>32</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>32</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>32</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>24</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>24</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>24</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>울진</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>21</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>21</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>대구ㆍ경상북도</province>
# 				<city>울릉도</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>22</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>22</tmn>
# 					<tmx>26</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>구름많고 소나기</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>23</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>제주</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>30</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>31</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 		</location>
#
# 		<location wl_ver="3">
# 				<province>제주도</province>
# 				<city>서귀포</city>
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-09 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 00:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>80</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-10 12:00</tmEf>
# 					<wf>흐리고 비</wf>
# 					<tmn>25</tmn>
# 					<tmx>27</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-11 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-12 12:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>26</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 00:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A02</mode>
# 					<tmEf>2023-07-13 12:00</tmEf>
# 					<wf>구름많음</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>30</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-14 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-15 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>40</rnSt>
# 				</data>
#
#
# 				<data>
# 					<mode>A01</mode>
# 					<tmEf>2023-07-16 00:00</tmEf>
# 					<wf>흐림</wf>
# 					<tmn>25</tmn>
# 					<tmx>28</tmx>
# 					<reliability></reliability>
# 					<rnSt>60</rnSt>
# 				</data>
#
#
# 		</location>
#
#
#
#
# 	</body>
# </description>
# </item>
# </channel>
# </rss>

# %%
url = "https://www.11st.co.kr/browsing/BestSeller.tmall?method=getBestSellerMain&xfrom=main^gnb"
try:
    res = req.urlopen(url)
    contents = res.read().decode('euc-kr')
except Exception as e:
    print(e)
else:
    print(res.info())
    print(contents[:4000])
# Out:
# Date: Thu, 06 Jul 2023 07:56:49 GMT
# Content-Type: text/html;charset=EUC-KR
# Set-Cookie: JSESSIONID=DC4B0DF8EDCB59F2EB1B1B483FB98873.Tomcat; Path=/; HttpOnly
# Vary: Accept-Encoding,User-Agent
# Access-Control-Allow-Credentials: true
# Transfer-Encoding: chunked
# Connection: close
# Server: Apache
#
#
#
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
#
#
#
# <html lang="ko">
# <head>
#
# <title>11번가 베스트 | 11번가</title>
# <meta name="Title" content="11번가 베스트 | 11번가">
# <meta name="Description" content=" 베스트! 다른 사람들은 지금 뭘 살까? 11번가 추천하는 실시간  베스트 아이템 순위!">
# <meta name="Keywords" content=" | 11번가">
# <meta http-equiv="Content-Type" content="text/html; charset=euc-kr">
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# <link rel="canonical" href="//www.11st.co.kr/browsing/BestSeller.tmall?method=getBestSellerMain&xfrom=main^gnb"/><link rel="alternate" media="only screen and (max-width: 640px)" href="//m.11st.co.kr/page/main/rank"/>
#
#
#
# <script type="text/javascript" src="//c.011st.com/html/experiment/experimentMetaInfo.js"></script>
#
# <script type="text/javascript" src="//c.011st.com/js/plab/plab-web-sdk-0.9.1.min.js"></script>
#
# <script>
#
#     var plabPageKey = '/best200/category';
#     try{
#
#         var params = {
#             projectKey : "11st_web",
#             domain : "11st.co.kr"
#         };
#         plab.initBy(params, experimentMetaInfo);
#
#     }catch (e) { console.log(e) };
#
#
# </script>
#
# <script type="text/javascript">
# 	!function(f,b,e,v,n,t,s) {if(f.fbq)return;n=f.fbq=function(){n.callMethod? n.callMethod.apply(n,arguments):n.queue.push(arguments)}; if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0'; n.queue=[];t=b.createElement(e);t.async=!0; t.src=v;s=b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t,s)}(window, document,'script', 'https://connect.facebook.net/en_US/fbevents.js');
# 	try {
# 		fbq('init', '2299486926950990');
# 		fbq('track', 'PageView');
# 	} catch (e) {
# 		console.error(e);
# 	}
# </script>
# <noscript>
# 	<img height="1" width="1" style="display:none" src="https://www.facebook.com/tr?id=2299486926950990&ev=PageView&noscript=1"/>
# </noscript>
# <script async src="https://www.googletagmanager.com/gtag/js?id=AW-876562370"></script>
# <script>
# 	try{
# 		window.dataLayer = window.dataLayer || [];
# 		function gtag(){dataLayer.push(arguments);}
# 		gtag('js', new Date());
# 		gtag('config', 'AW-876562370');
# 	} catch(e) {}
# </script>
#
#
# <script type="text/javascript">
#
#
# 	// Global Var
# 	var _IMG_PATH_  = "//s.011st.com";
# 	var _UPLOAD_IMG_PATH_  = "http://image.11st.co.kr";
# 	var _SSL_UPLOAD_IMG_PATH_ = "https://www.11st.co.kr/is";
# 	var _ACTION_CONTEXT_  = "";
# 	var _FILE_UPLOAD_PATH_ = "http://image.11st.co.kr";
# 	var _GNB_CONTEXT_PATH_ = "//www.11st.co.kr";
# 	var _ACTION_CONTEXT_URL_ = "http://www.11st.co.kr";
# 	var _SSL_ACTION_CONTEXT_URL_ = "https://www.11st.co.kr";
# 	var _SSL_IMG_PATH_ = "//s.011st.com";
# 	var _GLOBAL_CONTEXT_PATH_ = "http://globalshopping.11st.co.kr";
# 	var _BEAUTY_CONTEXT_PATH_ = "http://beauty.11st.co.kr";
# 	var _SOHO_CONTEXT_PATH_ = "http://soho.11st.co.kr";
# 	var _JS_PATH_ = "//c.011st.com";
# 	var _SSL_JS_PATH_ = "//c.011st.com";
#
# 	var _GNB_LOGIN_URL_ = "https://login.11st.co.kr/login/Login.tmall";
# 	var _GNB_LOGOUT_URL_ = "https://login.11st.co.kr/login/Logout.tmall";
# 	var _PRODUCT_DETAIL_URL_ = "https://www.11st.co.kr/product/SellerProductDetail.tmall?method=getSellerProductDetail&prdNo=";
#
# 	var _ENJOY_SEARCH_VAR_ = "NONE";
# 	var _ENJOY_SEARCH_KEY_YN_ = "N";
#
# 	var _SELLER_SHOP_DOMAIN_ = "https://shop.11st.co.kr";
#
# 	// 변경 권고
# 	var _CSS_URL_			= "//c.011st.com";
# 	var _SSL_CSS_URL_		= "//c.011st.com";
# 	var _IMG_URL_			= "//s.011st.com";
# 	var _SSL_IMG_URL_		= "//s.011st.com";
# 	var _UPLOAD_URL_		= "http://i.011st.com";
# 	var _SSL_UPLOAD_URL_	= "https://i.011st.com";
#
# 	var _LOGIN_TARGET_URL_ 	= "https://login.11st.co.kr";
#
# 	// TZONE Var
# 	var _TZONE_URL_			= "http://skt.11st.co.kr";
# 	var _TZONE_URL_HOME_	= "http://skt.11st.co.kr/html/tzone/tZoneMain.html";
# 	var _SELLER_URL_		= "http://seller.11st.co.kr";
# 	var _SOFFICE_URL_		= "http://soffice.11st.co.kr";
# 	var _DS_URL_			= "http://ds.11st.co.kr";
# 	var _MY11ST_URL_		= "http://buy.11st.co.kr/order/myTmall.tmall?method=getMyTmallMain";
# 	var _SHOPPINGCART_URL_ 	= "http://buy.11st.co.kr/cart/CartAction.tmall?method=getCartList";
# 	var _MYSELL_U

# %%
# 네이버 뉴스 가져오기
url = "https://n.news.naver.com/article/346/0000062543?cds=news_media_pc&type=editn"
try:
    res = req.urlopen(url)
    contents = res.read().decode('UTF-8')
    print(contents)
except Exception as e:
    print(e)
else:
    print(res.info())
# Out:
# <!doctype html>
# <html lang="ko" data-useragent="Python-urllib/3.11">
# 	<head>
# 		<meta charset="utf-8">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no" />
# 		<meta property="og:title" content="갈증날 때 청량음료? 더위 이기는데 ‘이 음료’가 더 좋아">
# 		<meta property="og:type" content="article">
# 		<meta property="og:url" content="https://n.news.naver.com/article/346/0000062543">
# 		<meta property="og:image" content="https://imgnews.pstatic.net/image/346/2023/07/06/0000062543_001_20230706050101310.jpg?type&#x3D;w800">
# 		<meta property="og:description" content="후텁지근한 날씨, 갈증이 느껴지면 가장 먼저 청량음료가 생각난다. 차가운 콜라나 사이다를 들이켜면 목마름이 해소되는 것 같지만, 이는 일시적일 뿐이다. 탄산음료엔 단맛을 내려 설탕과 액상과당이 들어간다. 몸에 다량의">
# 		<meta property="og:article:author" content="헬스조선 | 네이버">
# 		<meta name="twitter:card" content="summary_large_image">
# 		<meta name="twitter:title" content="갈증날 때 청량음료? 더위 이기는데 ‘이 음료’가 더 좋아">
# 		<meta name="twitter:site" content="네이버 뉴스">
# 		<meta name="twitter:creator" content="헬스조선">
# 		<meta name="twitter:image" content="https://imgnews.pstatic.net/image/346/2023/07/06/0000062543_001_20230706050101310.jpg?type&#x3D;w800">
# 		<meta name="twitter:description" content="후텁지근한 날씨, 갈증이 느껴지면 가장 먼저 청량음료가 생각난다. 차가운 콜라나 사이다를 들이켜면 목마름이 해소되는 것 같지만, 이는 일시적일 뿐이다. 탄산음료엔 단맛을 내려 설탕과 액상과당이 들어간다. 몸에 다량의">
# 		<meta name="napp-site-analysis" content="gdid=88156f6f_000000000000000000062543,service=news,collection=news,section=103">
# 		<title>갈증날 때 청량음료? 더위 이기는데 ‘이 음료’가 더 좋아</title>
# 			<link rel="stylesheet" href="https://static-nnews.pstatic.net/css/min/20230629/news.css">
# 			<link rel="shortcut icon" type="image/x-icon" href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" />
# 			<link rel="apple-touch-icon-precomposed" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />
# 			<link rel="apple-touch-icon-precomposed" size="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />
# 			<link rel="apple-touch-icon-precomposed" size="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />
# 			<link rel="apple-touch-icon-precomposed" size="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />
# 			<link rel="apple-touch-icon-precomposed" size="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />
# 					<script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script>
# 		<script>
# 			var g_ssc = nsc = "Mnews.v2";
# 			var g_default_area = "art";
#
# 			var svr = "one-service-r-20230629-230629-152229-5ff864545d-tnnv4";
# 			var nelo = {
# 				sampleNumber : 100,
# 				maxCount : 100,
# 				maxSendMessage : "로그 전송 최대치 도달"
# 			};
# 			var isGreendot = document.cookie.indexOf("MM_NEW=1") > -1;
# 			var isNewGreendot = document.cookie.indexOf("MM_NEW=2") > -1;
# 			var domain = "https://n.news.naver.com";
# 			var ajaxDomain = "";
# 			var newsDomain = "https://news.naver.com";
# 			var isAvailableDarkMode = false;
#
# 			var article = {
# 				isSubscribe: false,
# 				officeId: "346",
# 				articleId: "0000062543",
# 				sectionId : "103",
# 				gdid: "88156f6f_000000000000000000062543",
# 				type: "1",
# 				sectionInfo: {
# 					firstSection: "103",
# 					secondSection: "241",
# 					thirdSection: "000"
# 				},
# 				title: document.title
# 			};
#
#
#
# 			var office = {
# 				isChannel: true,
# 				isPressHome: true,
# 				name : "헬스조선",
# 				category : "전문지"
# 			};
#
# 			var refererType = "UNKNOWN";
#
# 			var searchQuery = (function() {
# 				var referrerLink = document.createElement("a");
# 				var emptySearch = "";
#
# 				referrerLink.href = document.referrer || "";
#
# 				if (referrerLink.host.indexOf("search.naver.com") === -1) {
# 					return emptySearch;
# 				}
#
# 				return decodeURIComponent(
# 					(
# 						referrerLink.search.match(/(?:\?|&)query\=([^&]+)/) || [ null, emptySearch ]
# 					)[1].replace(/\+/g, " ")
# 				);
# 			})();
#
# 			var divIds = [];
# 			var syncDivIds = [];
# 			var syncDivIdsForNonArticle = [];
#
# 			var unitIds = [];
# 			var syncUnitIds = [];
# 			var syncUnitIdsForNonArticle = [];
#
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			gladsdk.cmd.push(function() {
# 				gladsdk.setAdDeduplication("article_body_dedup");
# 				gladsdk.setGlobalConfig({ enablePersistAd: true });
#
# 				var adInfoList = [];
#
# 				adInfoList.push({
# 					seq: 1,
# 					unitId: "p_news_newsend",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
# 				adInfoList.push({
# 					seq: 2,
# 					unitId: "p_news_sidebox",
# 					sync: false,
# 					mobileOnly: false,
# 					article: false,
# 					directSalesPct: "0",
# 					calp: false
# 				});
#
# 				var userAgent = navigator.userAgent.toLowerCase();
#
# 				for (var i = 0; i < adInfoList.length; i++) {
# 					var adInfo = adInfoList[i];
#
# 					var divId = "nmap_c_" + article.officeId + "_" + article.articleId + "_" + article.sectionId + "_" + adInfo.seq;
#
# 					var unitId = adInfo.unitId;
# 					var mobileOnly = adInfo.mobileOnly;
# 					var sync = adInfo.sync;
# 					var isArticle = adInfo.article;
# 					var directSalesPct = adInfo.directSalesPct;
# 					var calp = adInfo.calp;
#
# 					if (mobileOnly == true) {
# 						if (/iphone|android|ipod/.test(userAgent) == false) {
# 							continue;
# 						}
# 					}
#
# 					var customParam = {
# 						sid1: article.sectionId,
# 						oid: article.officeId,
# 						gdid: article.gdid,
# 						pk: searchQuery,
# 						directSalesPct: directSalesPct
# 					};
#
# 					if (calp == true) {
# 						customParam.calp = "";
# 					}
#
# 					var adUnit = {
# 						adUnitId: unitId,
# 						adSlotElementId: divId,
# 						customParam: customParam
# 					};
#
# 					if (sync == true) {
# 						syncUnitIds.push(unitId);
# 						syncDivIds.push(divId);
#
# 						if (isArticle == false) {
# 							syncUnitIdsForNonArticle.push(unitId);
# 							syncDivIdsForNonArticle.push(divId);
# 						}
# 					} else {
# 						unitIds.push(unitId);
# 						divIds.push(divId);
# 					}
#
# 					gladsdk.defineAdSlot(adUnit);
# 				}
#
# 			});
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 		</script>
# 		<script src="https://static-nnews.pstatic.net/js/min/20230629/common.min.js"></script>
# 	</head>
# 	<body class="n_news fs2 as_mp_layout">
# 		<div class="end_container">
# 		<div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# 			<header role="banner" class="as_gnb as_type_a">
# 		<div class="header_inner" style="color: #767676;">
# 		<div class="Ngnb">
# 			<div id="_OFFICE_HEADER" class="office_header _OFFICE_HEADER">
# 				<div class="ofhd_float" style="background-color: #767676;">
# 					<div class="ofhd_float_inner">
# 						<a href="#" class="ofhd_float_back _BACK">이전 페이지</a>
# 						<div class="ofhd_float_head">
# 							<div class="ofhd_float_head_left">
# 								<a href="https://www.naver.com" class="ofhd_n_link" data-clk="gnb.naver"></a>
# 								<a href="https://news.naver.com" class="ofhd_news_link" data-clk="gnb.news"></a>
# 							</div>
# 							<h1 class="ofhd_float_title">
# 								<a href="https://media.naver.com/press/346" class="ofhd_float_title_text">헬스조선</a>
# 							</h1>
# 						</div>
# 						<div class="ofhd_float_subscribe _CHANNEL_BUTTON_WRAP" style="display:none;">
# 							<button type="button" class="_channel_add ofhd_float_subscribe_btn _CHANNEL_BUTTON _CHANNEL_ADD" data-clk-add="chmain346" data-clk-remove="chdelete346" data-text="구독" data-delay="1000" data-notification="true" data-notification-clk="notru">구독</button>
# 							<p id="_CHANNEL_MAIN_PROMOTION" class="ofhd_float_subscribe_tooltip" style="display:none;">
# 								<span class="ofhd_float_subscribe_tooltip_text"><strong>언론사를 구독하면 메인</strong>에서 바로 볼 수 있어요!</span>
# 							</p>
# 							<a id="_CHANNEL_LAYER_346_0000062543" href="#" class="ofhd_float_subscribe_layer _add _LINK" data-url-type="NAVERAPP_NEWS_CHANNEL" style="display: none;">
# 								<span class="ofhd_float_subscribe_layer_text">메인 뉴스판에서 헬스조선 주요뉴스를 <br> 볼 수 있습니다.</span>
# 								<span class="ofhd_float_subscribe_layer_link">보러가기</span>
# 							</a>
# 							<p id="_CHANNEL_REMOVE_LAYER_346_0000062543" class="ofhd_float_subscribe_layer _remove" style="display: none;">
# 								<span class="ofhd_float_subscribe_layer_text"><strong>헬스조선</strong> 언론사 구독 해지되었습니다.</span>
# 							</p>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 		<div id="_LNB_PARENT_WRAP" class="Nlnb is_fixed" style="z-index:3000; color: #767676;">
# 		<div id="_LNB_WRAP" class="Nlnb_menu Ntype_scroll " style="position: relative;">
# 			<div id="_LNB" class="Nlnb_menu_inner">
# 				<ul class="Nlnb_menu_list" role="tablist">
# 					<li class="Nlist_item _LNB_ITEM" role="tab"><a href="https://media.naver.com/press/346" class="Nitem_link" data-clk="prs_hom.mm"><span class="Nitem_link_menu">주요뉴스</span></a></li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab"><a href="https://media.naver.com/press/346/shortform" class="Nitem_link" data-clk="prs_hom.section"><span class="Nitem_link_menu">숏폼</span></a></li>
# 					<li class="Nlist_item _LNB_ITEM" role="tab"><a href="https://media.naver.com/press/346/ranking" class="Nitem_link" data-clk="prs_hom.section"><span class="Nitem_link_menu">랭킹</span></a></li>
# 				</ul>
# 			</div>
# 		</div>
# 		</div>
# 		</div>
# 	</header>
# <hr>
# <script>
# 	var svt = "20230706170524.800";
# 	var timestamp = svt.substr(0, 8);
# 	var isLogin = false;
# 	var uhv = "";
#
# 	var service = {
# 		news: true,
# 		entertain: false,
# 		sports: false,
# 		mnews: false,
# 		newsType: true
# 	};
# 	var serviceName = "news";
#
# 	var isProduction = true;
#
# </script>
# <div id="ct_wrap" class="ct_wrap">
# 	<div class="ct_scroll_wrapper">
# 		<div class="newsct_wrapper _GRID_TEMPLATE_COLUMN _STICKY_CONTENT"><div id="ct" class="newsct" role="main">
# <div class="media_end_head go_trans">
# 	<div class="media_end_head_top">
# 		<a href="http://health.chosun.com/" class="media_end_head_top_logo">
# 			<img src="https://mimgnews.pstatic.net/image/upload/office_logo/346/2020/09/15/logo_346_6_20200915191114.png" width="" height="32" alt="헬스조선" title="헬스조선" class="media_end_head_top_logo_img light_type">
# 			<img src="https://mimgnews.pstatic.net/image/upload/office_logo/346/2020/09/15/dark_logo_346_6_20200915184608.png" width="" height="32" alt="헬스조선" title="헬스조선" class="media_end_head_top_logo_img dark_type">
# 		</a>
# 		<div class="media_end_head_channel">
# 			<button type="button" class="media_end_head_channel_button _TOGGLE" data-target="_PICK_LAYER_346_0000062543">
# 				<i class="media_end_head_channel_pick">PICK</i>
# 				<i class="media_end_head_channel_info">안내</i>
# 			</button>
# 			<p id="_PICK_LAYER_346_0000062543" class="media_end_head_channel_layer" style="display: none;">
# 				<span class="media_end_head_channel_layer_text">언론사가 주요기사 및 심층기획으로<br>선정한 기사입니다.</span>
# 				<a href="#" class="media_end_head_channel_layer_link _MOVE_TO_NEWS">언론사별 바로가기</a>
# 				<button type="button" class="media_end_head_channel_layer_close _CLOSE" data-target="_PICK_LAYER_346_0000062543">닫기</button>
# 			</p>
# 		</div>
# 	</div>
# 	<div class="media_end_head_title">
# 		<h2 id="title_area" class="media_end_head_headline"><span>갈증날 때 청량음료? 더위 이기는데 ‘이 음료’가 더 좋아</span></h2>
# 	</div>
# 	<div class="media_end_head_info nv_notrans ">
# 		<div class="media_end_head_info_datestamp">
# 			<div class="media_end_head_info_datestamp_bunch">
# 				<em class="media_end_head_info_datestamp_term">입력</em><span class="media_end_head_info_datestamp_time _ARTICLE_DATE_TIME" data-date-time="2023-07-06 05:01:01">2023.07.06. 오전 5:01</span>
# 			</div>
# 			<a href="https://health.chosun.com/site/data/html_dir/2023/07/05/2023070502143.html" target="_blank" class="media_end_head_origin_link" data-clk="are.ori" data-gdid="346" data-extra="{&quot;lk&quot;:{&quot;oid&quot;:&quot;346&quot;,&quot;aid&quot;:&quot;ddd27e1b60f67a9b&quot;}}">기사원문</a>
# 		</div>		<div class="media_end_head_journalist">
# 			<a href="https://media.naver.com/journalist/346/78706" class="media_end_head_journalist_box" data-clk="ummore">
# 					<div class="media_end_head_journalist_thumb">
# 						<img src="https://mimgnews.pstatic.net/image/upload/spubs/BpG0000346/profile/2023/01/01/profile_171228612.jpg?type&#x3D;nf112_112" width="24" height="24">
# 					</div>
# 				<em class="media_end_head_journalist_name">이해림 기자</em>
# 			</a>
# 			<div id="_JOURNALIST_LAYER" class="media_end_head_journalist_layer _JOURNALIST_CARD" style="display: none;">
# 				<ul class="media_end_head_journalist_layer_list">
# 					<li class="media_end_head_journalist_layer_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# 						<div class="media_end_head_journalist_layer_div _LIKE_HIDE _LAZY_LOADING_WRAP">
# 							<div class="media_end_head_journalist_layer_thumb _LAZY_LOADING_ERROR_HIDE">
# 								<img data-src="https://mimgnews.pstatic.net/image/upload/spubs/BpG0000346/profile/2023/01/01/profile_171228612.jpg?type&#x3D;nf112_112" width="38" height="38" class="_LAZY_LOADING">
# 							</div>
# 							<div class="media_end_head_journalist_layer_text _reactionModule" id="_cheer_78706_layer" data-sid="JOURNALIST" data-cid="78706" data-ccounttype="period">
# 								<div class="media_end_head_journalist_layer_title">
# 									<em class="media_end_head_journalist_layer_name">이해림 기자</em>
# 									<div class="media_end_head_journalist_layer_btns _JOURNALIST_ID" data-journalistId="78706">
# 										<button type="button" class="media_end_head_journalist_btn_subscribe _SUBSCRIBE" data-channelKey="JOURNALIST_78706" data-clk="umsubs">구독</button>
# 										<button type="button" class="media_end_head_journalist_btn_subscribe is_on _UNSUBSCRIBE" data-channelKey="JOURNALIST_78706" data-type="journalist" data-messageValue="이해림" data-clk="umunsubs" style="display:none;">구독중</button>
# 									</div>
# 								</div>
# 								<dl class="media_end_head_journalist_layer_subscriber _button" data-type="cheer" data-ishiddenzerocount="true" data-isHiddenLabelAsZeroCount="true">
# 									<div class="media_end_head_journalist_layer_definition_wrap _SUBSCRIBE_COUNT_TEXT_WRAP">
# 										<dt>구독자</dt>
# 										<dd class="_SUBSCRIBE_COUNT_TEXT" data-maxcount="99999">0</dd>
# 									</div>
# 									<div class="media_end_head_journalist_layer_definition_wrap">
# 										<dt class="_label">응원수</dt>
# 										<dd class="_count">0</dd>
# 									</div>
# 								</dl>
# 							</div>
# 							<a href="https://media.naver.com/journalist/346/78706" class="media_end_head_journalist_layer_link" data-clk="ummore">더보기</a>
# 						</div>
# 					</li>
# 				</ul>
# 			</div>
# 		</div>
# 		<div class="media_end_head_info_variety">
# 			<div class="media_end_head_info_variety_left" id="commentFontGroup">
# 				<div class="media_end_head_info_variety_likeit _LIKE_HIDE as_likeit_improve">
# 					<!-- 좋아요 -->
# 					<div class="_reactionModule u_likeit nv_notrans" data-sid="NEWS" data-cid="ne_346_0000062543">
# 						<a class="u_likeit_button _face _LIKE_BUTTON" data-label="recommend" aria-haspopup="true" aria-pressed="false" data-clk="RTL.face">
# 							<span class="u_likeit_icons _icons">
# 								<span class="u_likeit_icon __reaction__zeroface"></span>
# 							</span>
# 							<span class="u_likeit_text _count">추천</span>
# 						</a>
# 						<ul class="u_likeit_layer _faceLayer" role="menu">
# 							<li class="u_likeit_list useful" role="menuitem">
# 								<a class="u_likeit_list_button _button off" data-type="useful" data-log="RTL.useful|RTL.unuseful" href="#" role="button" aria-selected="false" aria-pressed="false">
# 									<span class="u_likeit_list_name _label">쏠쏠정보</span>
# 									<span class="u_likeit_list_count _count">0</span>
# 								</a>
# 							</li>
# 							<li class="u_likeit_list wow" role="menuitem">
# 								<a class="u_likeit_list_button _button off" data-type="wow" data-log="RTL.wow|RTL.unwow" href="#" role="button" aria-selected="false" aria-pressed="false">
# 									<span class="u_likeit_list_name _label">흥미진진</span>
# 									<span class="u_likeit_list_count _count">0</span>
# 								</a>
# 							</li>
# 							<li class="u_likeit_list touched" role="menuitem">
# 								<a class="u_likeit_list_button _button off" data-type="touched" data-log="RTL.touched|RTL.untouched" href="#" role="button" aria-selected="false" aria-pressed="false">
# 									<span class="u_likeit_list_name _label">공감백배</span>
# 									<span class="u_likeit_list_count _count">0</span>
# 								</a>
# 							</li>
# 							<li class="u_likeit_list analytical" role="menuitem">
# 								<a class="u_likeit_list_button _button off" data-type="analytical" data-log="RTL.analytical|RTL.unanalytical" href="#" role="button" aria-selected="false" aria-pressed="false">
# 									<span class="u_likeit_list_name _label">분석탁월</span>
# 									<span class="u_likeit_list_count _count">0</span>
# 								</a>
# 							</li>
# 							<li class="u_likeit_list recommend" role="menuitem">
# 								<a class="u_likeit_list_button _button off" data-type="recommend" data-log="RTL.recommend|RTL.unrecommend" href="#" role="button" aria-selected="false" aria-pressed="false">
# 									<span class="u_likeit_list_name _label">후속강추</span>
# 									<span class="u_likeit_list_count _count">0</span>
# 								</a>
# 							</li>
# 						</ul>			</div>
# 					<!-- 좋아요 -->
# 				</div>
# 				<div class="media_end_head_info_variety_cmtcount _COMMENT_HIDE">
# 					<a href="/article/comment/346/0000062543" class="media_end_head_cmtcount_button _COMMENT_COUNT_VIEW" id="comment_count" data-clk="rplt" data-zero-allow="false" data-max-limit="true">댓글</a>
# 				</div>
# 			</div>
# 			<div class="media_end_head_info_variety_right">
# 				<!-- 요약봇 -->
# 				<div id="_SUMMARY_BUTTON" class="media_end_head_autosummary _auto_summary_wrapper _SUMMARY _LIKE_HIDE" data-officeId="346" data-articleId="0000062543">
# 					<a href="javascript:;" class="media_end_head_autosummary_button _toggle_btn _SUMMARY_BTN" data-clk="sum"><span class="blind">본문 요약봇</span></a>
# 					<div class="media_end_head_autosummary_layer_dimmed _SUMMARY_DIMMED" style="display: none;"></div>
# 					<div class="media_end_head_autosummary_layer _auto_summary_contents _SUMMARY_LAYER" style="display: none;">
# 						<div class="media_end_head_autosummary_layer_head">
# 							<strong class="media_end_head_autosummary_layer_head_tit">본문 요약봇<a href="https://help.naver.com/alias/news/news_022.naver" class="media_end_head_autosummary_help" data-clk="help">도움말</a></strong>
# 							<span class="media_end_head_autosummary_layer_head_txt">자동 추출 기술로 요약된 내용입니다. 요약 기술의 특성상 본문의 주요 내용이 제외될 수 있어, 전체 맥락을 이해하기 위해서는 기사 본문 전체보기를 권장합니다.</span>
# 							<a href="javascript:;" class="media_end_head_autosummary_layer_close _close_button _SUMMARY_CLOSE_BTN" data-clk="close"><span class="blind">닫기</span></a>
# 						</div>
# 						<div class="media_end_head_autosummary_layer_body">
# 							<div class="_contents_body _SUMMARY_CONTENT_BODY"></div>
# 						</div>
# 					</div>
# 				</div>
# 				<!-- TTS -->
# 					<div id="tts_player_div_wrap" class="media_end_head_tts nv_notrans">
# 						<button type="button" class="media_end_head_tts_run _TTS_SETTING_BTN" title="텍스트 음성 변환 서비스" data-clk="wtts"><span class="blind">텍스트 음성 변환 서비스 사용하기</span></button>
# 						<div class="media_end_head_tts_setlayer nv_notrans _TTS_SETTING_LAYER">
# 							<div class="media_end_head_tts_setlayer_select">
# 								<div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectGender">
# 									<em class="media_end_head_tts_option_tit">성별</em>
# 									<button type="button" class="media_end_head_tts_option" value="m" data-clk="ttsma">남성</button>
# 									<button type="button" class="media_end_head_tts_option" value="f" data-clk="ttsfe">여성</button>
# 								</div>
# 								<div class="media_end_head_tts_setlayer_select_bunch" id="ttsSelectSpeed">
# 									<em class="media_end_head_tts_option_tit">말하기 속도</em>
# 									<button type="button" class="media_end_head_tts_option" value="3" data-clk="ttssp">느림</button>
# 									<button type="button" class="media_end_head_tts_option" value="2" data-clk="ttssp">보통</button>
# 									<button type="button" class="media_end_head_tts_option" value="0" data-clk="ttssp">빠름</button>
# 								</div>
# 								<p class="media_end_head_tts_desc">이동 통신망을 이용하여 음성을 재생하면 별도의 데이터 통화료가 부과될 수 있습니다.</p>
# 								<button type="button" class="media_end_head_tts_apply _TTS_LISTEN_BTN" data-clk="ttsstart">본문듣기 시작</button>
# 							</div>
# 							<button type="button" class="media_end_head_tts_setlayer_close _TTS_SETTING_LAYER_CLOSE_BTN" data-clk="ttsclose"><span class="blind">닫기</span></button>
# 						</div>
# 					</div>
# 					<div id="tts_player_div"></div>		<!-- 폰트 사이즈 -->
# 				<div class="media_end_head_fontsize _font_size_config_wrapper _FONT_WRAP">
# 					<a href="#" class="media_end_head_fontsize_set _font_size_config_toggle_btn _FONT_BUTTON" data-clk="fsz"><span class="blind">글자 크기 변경하기</span></a>
# 					<div class="media_end_head_fontsize_setlayer _FONT_LAYER">
# 						<ul class="media_end_head_fontsize_setlayer_select">
# 							<li class="media_end_head_fontsize_option1 _opt">
# 								<a href="#" class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-value="1" data-clk="fsz1">가<em class="blind">1단계</em></a>
# 								<a href="#" class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-value="1" data-clk="fsz1">작게</a>
# 							</li>
# 							<li class="media_end_head_fontsize_option2 _opt">
# 								<a href="#" class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-value="2" data-clk="fsz2">가<em class="blind">2단계</em></a>
# 								<a href="#" class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-value="2" data-clk="fsz2">보통</a>
# 							</li>
# 							<li class="media_end_head_fontsize_option3 _opt">
# 								<a href="#" class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-value="3" data-clk="fsz3">가<em class="blind">3단계</em></a>
# 								<a href="#" class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-value="3" data-clk="fsz3">크게</a>
# 							</li>
# 							<li class="media_end_head_fontsize_option4 _opt">
# 								<a href="#" class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-value="4" data-clk="fsz4">가<em class="blind">4단계</em></a>
# 								<a href="#" class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-value="4" data-clk="fsz4">아주크게</a>
# 							</li>
# 							<li class="media_end_head_fontsize_option5 _opt">
# 								<a href="#" class="media_end_head_fontsize_option_text _FONT_LAYER_BUTTON" data-value="5" data-clk="fsz5">가<em class="blind">5단계</em></a>
# 								<a href="#" class="media_end_head_fontsize_option_name _FONT_LAYER_BUTTON" data-value="5" data-clk="fsz5">최대크게</a>
# 							</li>
# 						</ul>
# 					</div>
# 				</div>
# 				<div class="media_end_head_share nv_notrans">
# 					<a href="#" id="spiButton" class="u_btn_sns_share naver-splugin spi_sns_share nv_notrans _SHARE_BUTTON" onclick="return false" data-clk="ushr"
# 					   data-style="type_a"
# 					   data-url="https://n.news.naver.com/article/346/0000062543" data-canonical-url="https://news.naver.com/main/read.naver?mode=LSD&mid=sec&oid=346&aid=0000062543&sid1=001"
# 					   data-title="갈증날 때 청량음료? 더위 이기는데 ‘이 음료’가 더 좋아"
# 					   data-likeServiceId="NEWS"
# 					   data-likeContentsId="ne_346_0000062543"
# 					   data-mail-url="https://n.news.naver.com/article/346/0000062543?lfrom=mail"
# 					   data-blog-url="https://n.news.naver.com/article/346/0000062543?lfrom=blog"
# 					   data-blog-source-type="3"
# 					   data-blog-blog-id="naver"
# 					   data-cafe-url="https://n.news.naver.com/article/346/0000062543?lfrom=cafe"
# 					   data-cafe-source-type="3"
# 					   data-memo-url="https://n.news.naver.com/article/346/0000062543?lfrom=memo"
# 					   data-calendar-url="https://n.news.naver.com/article/346/0000062543?lfrom=calendar"
# 					   data-band-url="https://n.news.naver.com/article/346/0000062543?lfrom=band"
# 					   data-line-url="https://n.news.naver.com/article/346/0000062543?lfrom=line"
# 					   data-kakaotalk-url="https://n.news.naver.com/article/346/0000062543?lfrom=kakao"
# 					   data-kakaostory-display="off"
# 					   data-kakaotalk-image-url="https://imgnews.pstatic.net/image/346/2023/07/06/0000062543_001_20230706050101310.jpg?type=nf300_200"
# 					   data-facebook-url="https://n.news.naver.com/article/346/0000062543?lfrom=facebook"
# 					   data-twitter-url="https://n.news.naver.com/article/346/0000062543?lfrom=twitter"
# 					   data-mypeople-url="https://n.news.naver.com/article/346/0000062543?lfrom=mypeople"
# 					   data-friend-display="on"
# 					   data-friend-url="https://n.news.naver.com/article/346/0000062543?lfrom=friend">
# 						<span class="naver-splugin-c send_caption"><span class="u_hc">SNS 보내기</span></span>
# 					</a>
# 				</div>
# 				<div class="media_end_head_print">
# 					<a href="#" class="media_end_print_link _PRINT_BUTTON" data-print-url="/article/print/346/0000062543" data-clk="print"><span class="blind">인쇄하기</span></a>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div><div id="contents" class="newsct_body">
# 	<div id="newsct_article" class="newsct_article _article_body">
# 		<div id="dic_area" class="go_trans _article_content">
# 			<span class="end_photo_org"><div class="nbd_im_w _LAZY_LOADING_WRAP ">
# 	<div class="nbd_a _LAZY_LOADING_ERROR_HIDE" id="img_a1">
# 		<img id="img1" data-src="https://imgnews.pstatic.net/image/346/2023/07/06/0000062543_001_20230706050101310.jpg?type&#x3D;w647" class="_LAZY_LOADING" />
# 	</div>
# </div><em class="img_desc">시원한 물에 오미자를 오래 우린 ‘오미자차’는 여름철 더위와 갈증 해소에 효과적이다./사진=게티이미지뱅크</em></span><br><div>후텁지근한 날씨, 갈증이 느껴지면 가장 먼저 청량음료가 생각난다. 차가운 콜라나 사이다를 들이켜면 목마름이 해소되는 것 같지만, 이는 일시적일 뿐이다. 탄산음료엔 단맛을 내려 설탕과 액상과당이 들어간다. 몸에 다량의 당이 들어와 삼투압이 높아지면, 몸에 물이 더 필요해지며 갈증이 심해질 수 있다. <br><br>청량음료 대신 오미자를 우린 물은 어떨까. 오미자는 다양한 영양소가 풍부해 예로부터 약재로 사용됐다. 비타민C와 칼슘 등 무기질이 풍부해 신진대사를 촉진하는 데 좋고, 체력회복과 면역력 향상에도 도움이 된다. 오미자가 외부로부터 자신을 보호하기 위해 만든 ‘시잔드린’이라는 성분은 체내에서 항산화 물질로 바뀐다. 각종 세포 손상과 노화를 예방하는 데 이로울 뿐 아니라 기관지 내 염증 배출을 돕는 데도 효과적이다.<br><br>특히 여름에 마시는 오미자차는 온열질환을 예방하거나 증상을 개선하는데 도움을 준다. ‘동의보감’ 탕액편엔 ‘허로(虛勞)로 인해 몹시 여윈 상태’를 보하는데 오미자가 쓰인다고 기록돼 있다. 허로는 몸의 정기와 기혈이 허약해진 병증을 말한다. 이외에도 ‘오미자는 갈증을 씻어주고 땀을 덜 나게 하는 기능이 있어 집에서 차로 마시면 더위를 이길 수 있다’는 말이 나와 있다.<br><br>오미자는 찬물에 우리는 게 좋다. 날이 덥기 때문만은 아니다. 오미자를 뜨거운 물에 우려먹으면 오미자 특유의 떫고 신맛이 강해진다. 찬물에 오래 담가두는 ‘냉침(冷浸)법’으로 우려야 맛이 좋다. 깨끗이 씻은 오미자 30g을 생수 2L에 넣은 뒤 짧게는 12시간에서 길게는 24시간 정도 냉장고에 두면 된다. 취향에 따라 오미자 용량을 조절하거나 꿀을 첨가해 마실 수 있다. 시원한 오미자차에 앵두를 두 세 알 띄워 마시면 새콤달콤한 맛이 강해진다.<br><br>수입산 오미자는 진액이 적고 신맛이 약한 편인 반면, 국내산 오미자는 끈적이는 느낌과 신맛이 강한 경향이 있다. 겉보기 차이도 있다. 수입산 오미자는 겉에 하얀 가루가 묻어나는 반면, 국내산은 묻어나지 않는다. 오미자를 대량으로 구매했다면, 우선 식초를 몇 방울 떨어뜨린 물에 오미자를 씻고 물기를 없앤다. 이후 오미자에 붙은 가지를 떼어내고 냉동실에 넣어 두면 오래 보관할 수 있다. </div><br><br>
# 		</div>
# 	</div>
# 	<div class="byline">
# 		<p class="byline_p">
# 			<span class="byline_s">이해림 기자  lhr@chosun.com</span>
# 		</p>
# 	</div>
# 	<div class="newsct_journalist">
# 		<div class="newsct_journalist_inner">
# 			<h4 class="blind">기자 프로필</h4>
# 			<div class="media_journalistcard _JOURNALIST_CARD _MORE_WRAP">
# 				<div id="JOURNALIST_CARD_LIST" class="media_journalistcard_inner">
# 					<div class="media_journalistcard_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# 						<div class="media_journalistcard_item_inner">
# 							<div class="media_journalistcard_intro">
# 								<div class="media_journalistcard_summary">
# 									<span class="media_journalistcard_summary_press">
# 										<img src="https://mimgnews.pstatic.net/image/upload/office_logo/346/2020/09/15/logo_346_6_20200915191114.png" height="24" alt="헬스조선" title="" class="media_journalistcard_summary_press_img light_type">
# 										<img src="https://mimgnews.pstatic.net/image/upload/office_logo/346/2020/09/15/dark_logo_346_6_20200915184608.png" height="24" alt="헬스조선" title="" class="media_journalistcard_summary_press_img dark_type">
# 									</span>
# 									<div class="media_journalistcard_summary_inner _LAZY_LOADING_WRAP">
# 										<div class="media_journalistcard_summary_info">
# 											<a href="https://media.naver.com/journalist/346/78706" class="media_journalistcard_summary_photo _LAZY_LOADING_ERROR_HIDE" data-clk="mmore">
# 												<div class="media_journalistcard_summary_photo_inner">
# 													<img data-src="https://mimgnews.pstatic.net/image/upload/spubs/BpG0000346/profile/2023/01/01/profile_171228612.jpg?type&#x3D;nf112_112" width="40" height="40" alt="" class="media_journalistcard_summary_photo_inner_img _LAZY_LOADING _LAZY_LOADING_INIT_HIDE" style="display:none;">
# 												</div>
# 											</a>
# 											<a href="https://media.naver.com/journalist/346/78706" class="media_journalistcard_summary_text" data-clk="mmore">
# 											<span class="media_journalistcard_summary_name">
# 												<span class="media_journalistcard_summary_name_inner">
# 													<em class="media_journalistcard_summary_name_text">이해림 기자</em>
# 												</span>
# 											</span>
# 											</a>
# 										</div>
# 										<div class="subscribe_wrap _JOURNALIST_ID" data-journalistId="78706">
# 											<a href="#" class="subscribe _SUBSCRIBE" data-channelKey="JOURNALIST_78706" data-clk="msubs">
# 												<span class="subscribe_ico"><span>구독</span></span>
# 											</a>
# 											<a href="#" class="subscribe on _UNSUBSCRIBE" data-channelKey="JOURNALIST_78706" data-type="journalist" data-messageValue="이해림" style="display:none;" data-clk="munsubs">
# 												<span class="subscribe_ico"><span>구독중</span></span>
# 											</a>
# 										</div>
# 									</div>
# 									<span class="media_journalistcard_summary_subscribe">
# 										<span class="media_journalistcard_summary_subscribe_inner _SUBSCRIBE_COUNT_TEXT_WRAP">
# 											<i class="media_journalistcard_summary_subscribe_item">구독자</i> <em class="media_journalistcard_summary_subscribe_value _SUBSCRIBE_COUNT_TEXT">0</em>
# 										</span>
# 										<span class="media_journalistcard_summary_subscribe_inner _LIKE_HIDE">
# 											<div class="u_likeit_list_module _reactionModule" id="_cheer_78706_layer" data-sid="JOURNALIST" data-cid="78706" data-ccounttype="period">
# 												<span class="u_likeit_list_btn _button" data-type="cheer" data-ishiddenzerocount="true" data-isHiddenLabelAsZeroCount="true">
# 													<em class="u_txt _label">응원수</em>
# 													<em class="u_cnt _count">0</em>
# 												</span>
# 											</div>
# 										</span>
# 									</span>
# 								</div>
# 							</div>
# 							<div class="media_journalistcard_morenews">
# 								<ul class="media_journalistcard_morenews_list">
# 									<li class="media_journalistcard_morenews_item">
# 										<a href="/article/346/0000062375?type&#x3D;journalists" class="media_journalistcard_morenews_item_inner" data-clk="bestart">민망해 방치한 항문의 ‘이것’… 나중엔 암 된다고?</a>
# 									</li>
# 									<li class="media_journalistcard_morenews_item">
# 										<a href="/article/346/0000062509?type&#x3D;journalists" class="media_journalistcard_morenews_item_inner" data-clk="bestart">손톱 아래 흰색 반달모양… 안 보여도 괜찮을까?</a>
# 									</li>
# 								</ul>
# 							</div>
# 						</div>
# 					</div>
# 					<div id="_RECOMMEND_JOURNALIST" class="media_journalistcard_recommend media_journalistcard_recommend_is_on" style="display:none;">
# 						<div class="media_journalistcard_recommend_inner">
# 							<h4 class="media_journalistcard_recommend_title _RECOMMEND_JOURNALIST_WRAP">헬스조선의 구독 많은 기자를 구독해보세요!</h4>
# 							<script type="x-tmpl-mustache" class="_RECOMMEND_JOURNALIST_TEMPLATE">
# 							<ul class="media_journalistcard_recommend_list">
# 								{{#list}}
# 								<li class="media_journalistcard_recommend_item _SUBSCRIBE_ELE" data-subscribe-type="JOURNALIST">
# 									<div class="media_journalistcard_recommend_item_inner">
# 										<a href="{{reporterUrl}}" class="media_journalistcard_recommend_item_link" data-clk="bmmore">
# 											{{#imageUrl}}
# 											<span class="media_journalistcard_recommend_img_wrap"><img src="{{imageUrl}}" width="44" height="44" alt="" class="media_journalistcard_recommend_img"></span>
# 											{{/imageUrl}}
# 											<em class="media_journalistcard_recommend_name">{{reporterName}}</em>
# 										</a>
# 										{{#count}}
# 										<span class="media_journalistcard_recommend_subscribe">구독자 <em class="_SUBSCRIBE_COUNT_TEXT">{{count}}</em></span>
# 										{{/count}}
# 										<div class="subscribe_wrap">
# 											<a href="#" class="subscribe _SUBSCRIBE" data-channelKey="{{channelKey}}" data-clk="bmsubs">
# 												<span class="subscribe_ico"><span>구독</span></span>
# 											</a>
# 											<a href="#" class="subscribe on _UNSUBSCRIBE" data-channelKey="{{channelKey}}" data-type="journalist" data-messageValue="{{reporterName}}" data-clk="bmunsubs" style="display:none;">
# 												<span class="subscribe_ico"><span>구독중</span></span>
# 											</a>
# 										</div>
# 									</div>
# 								</li>
# 								{{/list}}
# 							</ul>
# 							</script>
# 							<a href="#" class="media_journalistcard_recommend_close _TOGGLE" data-target="_RECOMMEND_JOURNALIST" data-clk="bmclose">닫기</a>
# 						</div>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# 	<div class="copyright">
# 		<div class="c_inner">
# 			<p class="c_text">Copyright ⓒ 헬스조선. All rights reserved. 무단 전재 및 재배포 금지.</p>
# 		</div>
# 	</div>	<div class="media_end_categorize">
# 		<a href="#" class="media_end_categorize_link _categorize_title _TOGGLE" data-target="_ARTICLE_SECTION_GUIDE_LAYER">이 기사는 언론사에서 <em class="media_end_categorize_item">생활</em> 섹션으로 분류했습니다.</a>
# 		<div id="_ARTICLE_SECTION_GUIDE_LAYER" class="media_end_categorize_ct">
# 			<em class="media_end_categorize_ct_title">기사 섹션 분류 안내</em>
# 			<p class="media_end_categorize_ct_p">기사의 섹션 정보는 해당 언론사의 분류를 따르고 있습니다. 언론사는 개별 기사를 2개 이상 섹션으로 중복 분류할 수 있습니다.</p>
# 			<a href="#" class="media_end_categorize_ct_close _CLOSE" data-target="_ARTICLE_SECTION_GUIDE_LAYER">닫기</a>
# 		</div>
# 	</div>
# 	<div id="channelBanner" style="display:none;">
# 		<div class="media_end_channel_banner _LAZY_LOADING_WRAP">
# 			<a href="#" class="media_end_channel_banner_link _CHANNEL_BANNER _CHANNEL_ADD" data-clk-add="chbanner346" data-clk-remove="chsee346" data-notification="true" data-notification-clk="notbb">
# 				<div class="media_end_channel_banner_head _LAZY_LOADING_ERROR_HIDE">
# 					<div class="media_end_channel_banner_img">
# 						<img data-src="https://mimgnews.pstatic.net/image/upload/office_logo/346/2023/02/24/logo_346_57_20230224143254.jpg" class="_LAZY_LOADING _LAZY_LOADING_INIT_HIDE" width="40" height="40" alt="헬스조선" style="display:none;">
# 					</div>
# 				</div>
# 				<div class="media_end_channel_banner_body _before _CHANNEL_BANNER_ADD">
# 					<p class="media_end_channel_banner_add">구독</p>
# 					<p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 구독해보세요!</span></p>
# 				</div>
# 				<div class="media_end_channel_banner_body _after _CHANNEL_BANNER_REMOVE is_hidden">
# 					<p class="media_end_channel_banner_add is_disabled">구독중</p>
# 					<p class="media_end_channel_banner_txt"><span class="media_end_channel_banner_span"><strong>메인에서</strong> 바로 보는 언론사 편집 뉴스 지금 바로 확인해보세요!</span> <em>보러가기</em></p>
# 				</div>
# 			</a>
# 		</div>
# 	</div>
# 	<div id="channelBannerRecommendList"></div>
# 	<script type="x-tmpl-mustache" class="_CHANNEL_BANNER_RECOMMEND_LIST">
# 	<div class="office_preference _CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 	<div class="ofpr_recommend">
# 		<div class="ofpr_recommend_inner">
# 			<div class="ofpr_more_link">
# 				<h4 class="ofpr_tit">관심있는 언론사를 추가 구독해 보세요!</h4>
# 			</div>
# 			<ul class="ofpr_channel">
# 				{{#recommendList}}
# 				<li class="ofpr_item">
# 					<a href="#" class="ofpr_a _ALL_OFFICES_ITEM" data-officeId="{{officeId}}" data-officename="{{name}}" data-logo="{{logo}}" role="checkbox" aria-checked="false" data-clk-add="chwith" data-clk-remove="chwithno" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">
# 						<div class="ofpr_thumb"><img src="{{logo}}" class="ofpr_m" alt=""></div>
# 						<div class="ofpr_text">{{name}}</div>
# 						<span class="ofpr_badge">언론사 추가</span>
# 					</a>
# 				</li>
# 				{{/recommendList}}
# 			</ul>
# 			<div class="ofpr_btn_wrap">
# 				<div class="ofpr_btn_inner">
# 				<button type="button" class="ofpr_btn_more _ALL_OFFICE_LIST" data-clk="chwithall">언론사 전체보기</button>
# 				<button type="button" class="ofpr_btn_confirm _ALL_OFFICES_COMPLETE disabled" data-clk-disabled="chwithsetall" data-clk-enabled="chwithchoice" data-target="_CHANNEL_BANNER_RECOMMEND_LIST_WRAP">언론사 전체 선택</button>
# 				</div>
# 			</div>
# 			<button type="button" class="ofpr_recommend_close _TOGGLE" data-target="channelBannerRecommendList" data-clk="chclosing">닫기</button>
# 		</div>
# 	</div>
# 	</div>
# 	</script>
# 	<div class="promotion">
# 		<ul class="p_list">
# 			<li class="p_item">
# 				<a href="https://health.chosun.com/amirang/amirang.jsp?ref&#x3D;na_at_bo" class="p_link" data-clk="promo">암 환자에게 보내는 힐링의 메시지</a>
# 			</li>
# 			<li class="p_item">
# 				<a href="https://health.chosun.com/mildang365/mildang.jsp?ref&#x3D;na_at_bo" class="p_link" data-clk="promo">혈당 잡기 힘들 때 읽어야 할 지침서</a>
# 			</li>
# 		</ul>
# 	</div>	<div class="media_end_linked">
# 		<h3 class="media_end_linked_title">
# 			<a href="http://health.chosun.com/" class="media_end_linked_title_inner">
# 				<img src="https://mimgnews.pstatic.net/image/upload/office_logo/346/2020/09/15/logo_346_6_20200915191114.png" width="" height="26" alt="헬스조선" title="헬스조선" class="media_end_linked_title_img light_type">
# 				<img src="https://mimgnews.pstatic.net/image/upload/office_logo/346/2020/09/15/dark_logo_346_6_20200915184608.png" width="" height="26" alt="헬스조선" title="헬스조선" class="media_end_linked_title_img dark_type">
# 			</a>
# 			주요뉴스<span class="media_end_linked_title_desc">해당 언론사에서 선정하며 <em>언론사 페이지(아웃링크)</em>로 이동해 볼 수 있습니다.</span>
# 		</h3>
# 		<ul class="media_end_linked_list">
# 			<li class="media_end_linked_item"><a href="https://health.chosun.com/site/data/html_dir/2023/07/05/2023070502279.html" target="_blank" class="media_end_linked_item_inner" data-clk="are.link" data-gdid="346" data-extra="{&quot;lk&quot;:{&quot;oid&quot;:&quot;346&quot;,&quot;aid&quot;:&quot;eea37077d70abb37&quot;}}">사망 임박했는데… 가족의 시한부 선고, 어떻게 전하실 건가요?</a></li>
# 			<li class="media_end_linked_item"><a href="https://health.chosun.com/site/data/html_dir/2023/07/04/2023070401877.html" target="_blank" class="media_end_linked_item_inner" data-clk="are.link" data-gdid="346" data-extra="{&quot;lk&quot;:{&quot;oid&quot;:&quot;346&quot;,&quot;aid&quot;:&quot;49b5d452d567f812&quot;}}">내 뱃속에 이상한 주머니들이? 기묘한 질환 '게실염'</a></li>
# 			<li class="media_end_linked_item"><a href="https://health.chosun.com/site/data/html_dir/2023/07/03/2023070301832.html" target="_blank" class="media_end_linked_item_inner" data-clk="are.link" data-gdid="346" data-extra="{&quot;lk&quot;:{&quot;oid&quot;:&quot;346&quot;,&quot;aid&quot;:&quot;f10e23133dae2393&quot;}}">[건강잇숏] 뱃살 빼고 싶은 사람이 꼭 먹어야 하는 영양소</a></li>
# 		</ul>
# 	</div>
# 	<div class="r_group_comp ad_box _da_banner is_border_none">
# 		<div id="nmap_c_346_0000062543_103_1" class="ad_area _AD_WRAP _PERSIST_HEIGHT" data-unitid="p_news_newsend" data-mobileonly="false" data-persist="1_ad" data-sync="false" data-article="false"></div>
# 	</div>
# 	<script>
# 	window.__htExternalUrl = window.__htExternalUrl || {};
# 	window.__htExternalUrl["like"] = "https://news.like.naver.com/js/reaction/dist/reaction.min.js";
# 	window.__htLikeOption = {
# 		type: "multi",
# 		cssId: "news",
# 		domain: "https://news.like.naver.com",
# 		isMobile: true,
# 		isHiddenLabel: false,
# 		isHiddenCount: false,
# 		isHiddenZeroCount: false,
# 		isUsedLabelAsZeroCount: false,
# 		isDebugMode: false,
# 		isDuplication: false,
# 		isHiddenLayerAfterSelection: true,
# 		clicklog: function(el, name) {
# 			nclkWrap.send({
# 				$this: $(el),
# 				sArea: name
# 			});
# 		}
# 	};
# 	window.__htLikeOption["isZeroFace"] = true;
# 	</script>
# 	<div class="ends_btn _PERSIST_HEIGHT _LIKE_HIDE as_likeit_improve" data-persist="0_faceLike">
# 		<div class="ends_btn_head">
# 			<strong class="ends_head_title">이 기사를 추천합니다</strong>
# 			<button type="button" class="ends_help_btn _TOGGLE" data-clk="RTC.info" data-target="_LIKE_INFO_LAYER" data-classValue="is_hidden"></button>
# 			<div id="_LIKE_INFO_LAYER" class="ends_help_layer is_hidden">
# 				<p class="ends_help_desc">기사 추천은 24시간 내 50회까지 참여할 수 있습니다.</p>
# 				<button class="ends_help_close _TOGGLE" data-clk="RTC.infoclose" data-target="_LIKE_INFO_LAYER" data-classValue="is_hidden"><span class="blind">닫기</span></button>
# 			</div>
# 		</div>
# 		<div class="_reactionModule u_likeit" data-sid="NEWS" data-cid="ne_346_0000062543" id="likeItCountViewDiv" style="visibility: visible;">
# 			<ul class="u_likeit_layer _faceLayer" role="menu">
# 				<li class="u_likeit_list useful" role="menuitem">
# 					<a class="u_likeit_list_button _button off" data-type="useful" data-log="RTC.useful|RTC.unuseful" href="#" role="button" aria-selected="false" aria-pressed="false">
# 						<span class="u_likeit_list_name _label">쏠쏠정보</span>
# 						<span class="u_likeit_list_count _count">0</span>
# 					</a>
# 				</li>
# 				<li class="u_likeit_list wow" role="menuitem">
# 					<a class="u_likeit_list_button _button off" data-type="wow" data-log="RTC.wow|RTC.unwow" href="#" role="button" aria-selected="false" aria-pressed="false">
# 						<span class="u_likeit_list_name _label">흥미진진</span>
# 						<span class="u_likeit_list_count _count">0</span>
# 					</a>
# 				</li>
# 				<li class="u_likeit_list touched" role="menuitem">
# 					<a class="u_likeit_list_button _button off" data-type="touched" data-log="RTC.touched|RTC.untouched" href="#" role="button" aria-selected="false" aria-pressed="false">
# 						<span class="u_likeit_list_name _label">공감백배</span>
# 						<span class="u_likeit_list_count _count">0</span>
# 					</a>
# 				</li>
# 				<li class="u_likeit_list analytical" role="menuitem">
# 					<a class="u_likeit_list_button _button off" data-type="analytical" data-log="RTC.analytical|RTC.unanalytical" href="#" role="button" aria-selected="false" aria-pressed="false">
# 						<span class="u_likeit_list_name _label">분석탁월</span>
# 						<span class="u_likeit_list_count _count">0</span>
# 					</a>
# 				</li>
# 				<li class="u_likeit_list recommend" role="menuitem">
# 					<a class="u_likeit_list_button _button off" data-type="recommend" data-log="RTC.recommend|RTC.unrecommend" href="#" role="button" aria-selected="false" aria-pressed="false">
# 						<span class="u_likeit_list_name _label">후속강추</span>
# 						<span class="u_likeit_list_count _count">0</span>
# 					</a>
# 				</li>
# 			</ul>	</div>
# 		<div id="likeItSTimeLineShareDiv" style="display:none" class="u_likeit_module u_btn_likeit_on"></div>
# 		<div id="likeItScrollDiv" style="display:none" class="u_likeit_module">
# 			<div class="u_likeit_friends" id="likeItFriendListDiv"></div>
# 		</div>
# 	</div>	<div class="ends_addition" id="endAdditionContainer">
#
#
# 		<script>
# 			window.__htExternalUrl = window.__htExternalUrl || {};
# 			window.__htExternalUrl["share"] = "https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.js";
# 			window.__htShareOption = {
# 				"scriptUrl": window.__htExternalUrl["share"],
# 				"evKey": "news",
# 				"dimmed": "fixed",
# 				"serviceName": "뉴스",
# 				"sourceName": "헬스조선"
# 			};
# 			if (isAvailableDarkMode) {
# 				window.__htShareOption["darkMode"] = true;
# 			}
# 		</script>
# 		<div id="spiLayer" style="display:none;">
# 			<div class="spi_wrap layer_share_on">
# 				<div class="spi">
# 					<div class="spug">
# 						<a href="#" class="naver-splugin _spi_release spi_ico _btn_postbtn sns_share" data-clk="dshr"
# 						   data-style="type_a"
# 						   data-url="https://n.news.naver.com/article/346/0000062543" data-canonical-url="https://news.naver.com/main/read.naver?mode=LSD&mid=sec&oid=346&aid=0000062543&sid1=001"
# 						   data-title="갈증날 때 청량음료? 더위 이기는데 ‘이 음료’가 더 좋아"
# 						   data-likeServiceId="NEWS"
# 						   data-likeContentsId="ne_346_0000062543"
# 						   data-mail-url="https://n.news.naver.com/article/346/0000062543?lfrom=mail"
# 						   data-blog-url="https://n.news.naver.com/article/346/0000062543?lfrom=blog"
# 						   data-blog-source-type="3"
# 						   data-blog-blog-id="naver"
# 						   data-cafe-url="https://n.news.naver.com/article/346/0000062543?lfrom=cafe"
# 						   data-cafe-source-type="3"
# 						   data-memo-url="https://n.news.naver.com/article/346/0000062543?lfrom=memo"
# 						   data-calendar-url="https://n.news.naver.com/article/346/0000062543?lfrom=calendar"
# 						   data-band-url="https://n.news.naver.com/article/346/0000062543?lfrom=band"
# 						   data-line-url="https://n.news.naver.com/article/346/0000062543?lfrom=line"
# 						   data-kakaotalk-url="https://n.news.naver.com/article/346/0000062543?lfrom=kakao"
# 						   data-kakaostory-display="off"
# 						   data-kakaotalk-image-url="https://imgnews.pstatic.net/image/346/2023/07/06/0000062543_001_20230706050101310.jpg?type=nf300_200"
# 						   data-facebook-url="https://n.news.naver.com/article/346/0000062543?lfrom=facebook"
# 						   data-twitter-url="https://n.news.naver.com/article/346/0000062543?lfrom=twitter"
# 						   data-mypeople-url="https://n.news.naver.com/article/346/0000062543?lfrom=mypeople"
# 						   data-friend-display="on"
# 						   data-friend-url="https://n.news.naver.com/article/346/0000062543?lfrom=friend"
# 						   data-button="postbtn"></a>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
#
# 		<div id="_TOMAIN_INFO" class="tomain_info _LIKE_HIDE" style="display: none;">
# 			<p class="tomain_info_layer">
# 				<strong class="tomain_info_head">모두에게 보여주고 싶은 기사라면<i>?</i><span class="tomain_info_betaicon">beta</span></strong>
# 				<span class="tomain_info_body">
# 					<strong class="tomain_info_point">이 기사를 추천합니다 </strong><span class="tomain_info_text">버튼을 눌러주세요. <br> 집계 기간 동안 추천을 많이 받은 기사는 네이버 자동 기사배열 영역에 추천 요소로 활용됩니다.</span>
# 				</span>
# 				<a href="#" class="tomain_info_close _CLOSE" data-target="_TOMAIN_INFO">레이어 닫기</a>
# 			</p>
# 		</div>
# 	</div>	<div class="_VALID_SERIES" data-component-id=""></div>
# 	<div class="media_end_linked_more">
# 		<div class="media_end_linked_more_inner">
# 			<a href="https://media.naver.com/press/346" class="media_end_linked_more_link" data-clk="phome" data-gdid="346"><em class="media_end_linked_more_point">헬스조선</em> 언론사홈 바로가기</a>
# 		</div>
# 	</div>
# 	<script>
# 		window.__htExternalUrl = window.__htExternalUrl || {};
# 		window.__htExternalUrl["tip"] = "https://ssl.pstatic.net/dicimg/tip/tip_m.js";
# 		window.__htExternalUrl["pcTip"] = "https://ssl.pstatic.net/dicimg/tip/tip_pc.js";
#
# 		window.__htExternalUrl["handOff"] = {
# 			"category": "news_article",
# 			"apiDomain": "https://sidekick.fever.naver.com"
# 		};
# 	</script>	<div id="_MODAL_LAYER_FOR_UNSUBSCRIBER_PROMOTION" class="subscribe_cta_layer">
# 		<div class="cta_layer_inner">
# 		<button type="button" class="cta_btn as_subscribe _CHANNEL_ADD" data-clk-add="mediaflw" data-delay="1000" data-notification="true">
# 			<div class="cta_thumb">
# 				<img data-src="https://mimgnews.pstatic.net/image/upload/office_logo/346/2023/02/24/logo_346_57_20230224143254.jpg" class="_LAZY_LOADING" alt="" width="28" height="28" onerror="this.outerHTML='<span class=&quot;noimage&quot;></span>'">
# 			</div>
# 			<span class="cta_text"><em class="cta_text_em">언론사</em> 구독 후 기사보기</span>
# 			<i class="cta_arrow"></i>
# 		</button>
# 		<button type="button" class="cta_btn _UNSUBSCRIBER_PROMOTION_CLOSE" data-clk="medianoflw">
# 			<span class="cta_text">구독 없이 계속 보기</span>
# 		</button>
# 		</div>
# 	</div>
# 	<div id="_MODAL_LAYER_FOR_UNSUBSCRIBER_PROMOTION_JOURNALIST" class="subscribe_cta_layer">
# 		<div class="cta_layer_inner">
# 			<button type="button" class="cta_btn as_subscribe _UNSUBSCRIBER_JOURNALIST_SERIES_PROMOTION_SUBSCRIBE _UNSUBSCRIBER_JOURNALIST_SERIES_PROMOTION_CLOSE" data-type="JOURNALIST" data-expires="3" data-channelKey="JOURNALIST_78706" data-clk="jflw">
# 				<div class="cta_thumb as_type_person">
# 					<img data-src="https://mimgnews.pstatic.net/image/upload/spubs/BpG0000346/profile/2023/01/01/profile_171228612.jpg?type&#x3D;nf112_112" class="_LAZY_LOADING" alt="" width="28" height="28" onerror="this.outerHTML='<span class=&quot;noimage&quot;></span>'">
# 				</div>
# 				<span class="cta_text"><em class="cta_text_em">기자</em> 구독 후 기사보기</span>
# 				<i class="cta_arrow"></i>
# 			</button>
# 			<button type="button" class="cta_btn _UNSUBSCRIBER_JOURNALIST_SERIES_PROMOTION_CLOSE" data-type="JOURNALIST" data-expires="7" data-clk="jnoflw">
# 				<span class="cta_text">구독 없이 계속 보기</span>
# 			</button>
# 		</div>
# 	</div>
# </div>
# </div>
# 	<div class="box1 more_news2">
# <h4>
# ...
# 											<img data-src="https://scs-phinf.pstatic.net/MjAyMjEwMjJfMTAz/MDAxNjY2Mzk2MjcxMzc5.e10YfMmSBOgIt-lREtYDiujJ_X2vN2AfpApYiKbHx-cg.KiOyJa41mEM37gZP3oSgqkcpdfBZnhYXZGZvaN7PM88g.PNG/image%7Cpremium%7Cchannel%7Cthebigrich%7C2022%7C10%7C22%7C1666396271359.png?type&#x3D;nfs200_200" data-scroll="true" class="_LAZY_LOADING" width="18" height="18">
# 										</div>
# 										<div class="rl_author_name">책먹는여자</div>
# 									</div>
# 								</div>
# 								<div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# 									<div class="rl_border">
# 										<img data-src="https://scs-phinf.pstatic.net/MjAyMzA3MDRfMTUz/MDAxNjg4NDM5MjMyNTky.yiMw93_2Nx2rECgQCbadpvGO5vSgXZWDnRskyj051Zcg.TE6L21mRRZ2LIu6nK9vISybVrqTOiQiGppma_6lo8Xsg.PNG/%ED%94%84%EC%BD%98_(29).png?type&#x3D;nf190_130" data-scroll="true" class="_LAZY_LOADING" width="95" height="65">
# 										<span class="rl_btn_play"><em class="blind">동영상 기사</em></span>
# 									</div>
# 								</div>
# 							</a>
# 						</li>
# 						<li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# 							<a href="https://contents.premium.naver.com/elanvital/photoclass/contents/230704192834870vx?from&#x3D;news_arp_global" class="rl_link_end" data-clk="arp.ptextg" data-score="0.7374755965467485" data-recommended-type="GLOBAL">
# 								<div class="rl_content">
# 									<p class="rl_txt">
# 										반영 사진 잘 찍는 법
# 									</p>
# 									<div class="rl_author">
# 										<div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# 											<img data-src="https://scs-phinf.pstatic.net/MjAyMjAyMjFfMjc1/MDAxNjQ1Mzk2NjY0MjA2.JmfR3zzhuh_Y93_ep3D9T8DzvBI40gtXc4qF98N8Yygg.MqH0xZfBmubqicuOv098sDcLlX6XI3IrQq2P6c6Q4acg.JPEG/image%7Cpremium%7Cchannel%7Celanvital%7C2022%7C02%7C21%7C1645396664167.jpg?type&#x3D;nfs200_200" data-scroll="true" class="_LAZY_LOADING" width="18" height="18">
# 										</div>
# 										<div class="rl_author_name">엘란비탈 포토클래스</div>
# 									</div>
# 								</div>
# 								<div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# 									<div class="rl_border">
# 										<img data-src="https://scs-phinf.pstatic.net/MjAyMzA3MDRfMzUg/MDAxNjg4NDY2MjQwNDQw.644UAwkJuDLvSoP7lazZ89epcVjUQFk7PCwVBmKtIpgg.h-LmAob_bpkvSyzMMYtCLps931wv6aB0KuONp3XwN0gg.JPEG/%ED%81%AC%EB%A6%AC%EC%97%90%EC%9D%B4%ED%84%B0-%EB%85%B8%ED%8A%B81.jpg?type&#x3D;nf190_130" data-scroll="true" class="_LAZY_LOADING" width="95" height="65">
# 									</div>
# 								</div>
# 							</a>
# 						</li>
# 						<li class="rl_item _LAZY_LOADING_WRAP" data-loading-error-allowed="true">
# 							<a href="https://contents.premium.naver.com/thebell/stock/contents/230704180327078co?from&#x3D;news_arp_global" class="rl_link_end" data-clk="arp.ptextg" data-score="0.8666292348556481" data-recommended-type="GLOBAL">
# 								<div class="rl_content">
# 									<p class="rl_txt">
# 										파이낸셜스토리 반환점 돈 SKC는 잘 하고 있을까
# 									</p>
# 									<div class="rl_author">
# 										<div class="rl_author_thumb _LAZY_LOADING_ERROR_HIDE">
# 											<img data-src="https://scs-phinf.pstatic.net/MjAyMTA1MTFfMjU1/MDAxNjIwNzE3NzE2NDU3.ybD4MjqNT23dR2rvtcpmg3Jf5smXxuJ-4w2BNidwucQg.0uh5Sd54bl_5EiDapKBnUA15rgV7muQxXrXDhB6bfbUg.JPEG/image%7Cpremium%7Cchannel%7Cstock%7C2021%7C05%7C11%7C1620717716430.jpg?type&#x3D;nfs200_200" data-scroll="true" class="_LAZY_LOADING" width="18" height="18">
# 										</div>
# 										<div class="rl_author_name">thebellstock</div>
# 									</div>
# 								</div>
# 								<div class="rl_img _LAZY_LOADING_ERROR_HIDE">
# 									<div class="rl_border">
# 										<img data-src="https://scs-phinf.pstatic.net/MjAyMzA3MDRfOTcg/MDAxNjg4NDYwMTYzOTAy.q2faKrdhp0FLjSU3UbLZCbWbGcgmHJEQXMrt4oziRkog.SqDH6onX0MDmwAQFbasxSJ9UqfSoPoIRvvmkDn3uuDAg.JPEG/SKC_2222.jpg?type&#x3D;nf190_130" data-scroll="true" class="_LAZY_LOADING" width="95" height="65">
# 									</div>
# 								</div>
# 							</a>
# 						</li>
# 					</ul>
# 				</div>
# 			</div>
# 		</div>
# 		<div class="pg ra_paginate">
# 			<div class="pg_num_area pg_num_area_v2">
# 				<button type="button" class="pg_btn_prev _FLICKING_PREV" data-clk="arp.bprv"><span class="blind">이전 콘텐츠들 보기</span></button>
# 				<div class="_FLICKING_INDICATOR" data-count="3"></div>
# 				<div class="pg_line"></div>
# 				<div class="pg_num pg_num">3</div>
# 				<button type="button" class="pg_btn_next _FLICKING_NEXT" data-clk="arp.bnxt"><span class="blind">다음 콘텐츠들 보기</span></button>
# 			</div>
# 		</div>
# 		<script type="x-tmpl-mustache" class="_FLICKING_INDICATOR_TEMPLATE _PC">
# 			{{#selected}}
# 			<div class="pg_num pg_num_cur">{{number}}</div>
# 			{{/selected}}
# 		</script>
# 	</div>
# </div>
# </div>
# 		<div class="outside_area _OUTSIDE_AREA">
# 			<div class="outside_area_inner _GRID_TEMPLATE_COLUMN_ASIDE _OUTSIDE_AREA_INNER"></div>
# 		</div>
# 		<aside class="main_aside _MAIN_ASIDE">
# 			<div class="main_aside_inner _MAIN_ASIDE_INNER">
# 			<h3 class="blind">구독</h3>
# 			<script type="x-tmpl-mustache" class="_LAZY_LOADING_IFRAME">
# 			<iframe class="_aside _GRID_TEMPLATE_ASIDE_IFRAME" src="https://news.naver.com/aside?oid=346" data-allow-domain="https://news.naver.com" style="visibility: hidden;" frameborder="no" scrolling="no" width="100%"></iframe>
# 			</script>
# 			</div>
# 		</aside>
# 	</div>
# </div>
# <div class="media_end_tts_ticker _FADE_LAYER" id="_media_end_tts_ticker" style="display: none;">
# 	<p class="media_end_tts_ticker_text" style="display: block;">본문 듣기를 <em class="media_end_tts_ticker_point">종료</em>하였습니다.</p>
# </div>
# <div class="tomain_ticker _TOMAIN_RECOMMAND_LAYER _FADE_LAYER" style="display: none;">이 기사를 <em class="tomain_ticker_point">추천</em>했습니다.
# </div>
# <div class="tomain_ticker _TOMAIN_CANCEL_LAYER _FADE_LAYER" style="display: none;">추천을 <em class="tomain_ticker_point">취소</em>했습니다.
# </div><hr>
# 	<div class="u_ft _STICKY_FOOTER">
# 		<div class="u_ft_inner">
# 		<a href="#" class="r_pg_top show _MOVE_TOP" id="goTop" data-clk="fot.top" style="display:none;">맨위로</a>
# 		<footer role="contentinfo">
# 			<p id="u_ftlkw" class="u_ftlkw">
# 					<a href="https://nid.naver.com/nidlogin.login?svctype=262144" class="u_ftlk _LINK" data-url="https://nid.naver.com/nidlogin.login?svctype=262144" data-pc-url="https://nid.naver.com/nidlogin.login" data-clk="fot.login">로그인</a>
# 				<a href="https://m.naver.com/services.html?f=svc.news" class="u_ftlk _LINK" data-url="https://m.naver.com/services.html?f=svc.news" data-pc-url="https://www.naver.com/more.html" data-clk="fot.sitemap">전체서비스</a>
# 			</p>
# 			<p class="u_cr">
# 				<span class="u_ftm">
# 					<span class="u_cri u_cri_v1"><a href="https://m.news.naver.com/ombudsman/index" class="u_cra _LINK" data-url="https://m.news.naver.com/ombudsman/index" data-pc-url="https://news.naver.com/main/ombudsman/index.naver">서비스안내</a></span>
# 					<span class="u_cri u_cri_v1"><a href="https://help.naver.com/alias/news/news_007.naver" class="u_cra" data-clk="fot.help">뉴스도움말</a></span>
# 					<span class="u_cri u_cri_v1"><a href="https://help.naver.com/alias/news/news_001.naver" class="u_cra" data-clk="fot.report">오류신고</a></span>
# 				</span>
# 				<span class="u_copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며, 이를 무단<br>이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</span>
# 				<span class="u_cri"><span class="copymark">ⓒ</span> <a href="https://www.navercorp.com" class="u_cra_v1" data-clk="fot.navercorp">NAVER Corp.</a></span>
# 					<span class="u_cri"><span class="copymark">ⓒ</span> <a class="u_cra_v1">헬스조선</a></span>
# 			</p>
# 		</footer>
# 		</div>
# 	</div><div id="_MY_FEED_CANCEL_MODAL" class="subscribe_dimmed is_hidden" style="display:none;">
# 	<div class="subscribe_alert">
# 		<p class="subscribe_alert_p _message _MY_FFED_CANCEL_MODAL_MESSAGE">
# 		</p>
# 		<div class="subscribe_alert_btns">
# 			<a href="#" class="subscribe_alert_btn _CANCEL_YES_BTN _TOGGLE" data-target="_MY_FEED_CANCEL_MODAL" data-classValue="is_hidden">예</a>
# 			<a href="#" class="subscribe_alert_btn _TOGGLE" data-target="_MY_FEED_CANCEL_MODAL" data-classValue="is_hidden">아니오</a>
# 		</div>
# 	</div>
# </div>
# <script type="x-tmpl-mustache" class="_MY_FEED_CANCEL_MODAL_TEMPLATE">
# 			{{#series}}
# 			<span class="subscribe_alert_p_ellipsis">{{value}}</span><br>연재 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc">해당 연재는 <em>구독</em>에서 제외됩니다.</span>
# 			{{/series}}
# 			{{#journalist}}
# 			{{value}} 기자의 기사<br> 구독을 취소하시겠습니까? <span class="subscribe_alert_p_dsc"><em>구독</em>에서 해당 기자의 기사가 제외됩니다.</span>
# 			{{/journalist}}
# </script>
# <div id="_MODAL_LAYER_FOR_NOTIFICATION" class="modal is_hidden"></div>
# <div id="_MODAL_LAYER_FOR_NOTIFICATION_ALL" class="modal is_hidden"></div>
# <script type="x-tmpl-mustache" class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION">
# <div class="m_dimmed"></div>
# <div class="m_notification is_single">
# 	<strong class="mn_ok">구독완료</strong>
# 	{{#officeInfos}}
# 	<div class="mn_text">
# 		<h4 class="mn_h">{{officeName}} 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<p class="mn_p">언론사의 주요 콘텐츠를 <br> 네이버에서 빠르게 확인할 수 있습니다.</p>
# 	</div>
# 	{{/officeInfos}}
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE" data-clk="{{nclk}}yes">알림받기</button>
# 	</div>
# </div>
# </script>
# <script type="x-tmpl-mustache" class="_MODAL_LAYER_TEMPLATE_FOR_NOTIFICATION_ALL">
# <div class="m_dimmed"></div>
# <div class="m_notification">
# 	<strong class="mn_ok">구독완료</strong>
# 	<div class="mn_text">
# 		<h4 class="mn_h">언론사의 주요 뉴스를 <br> <span class="m_em">알림</span>으로 받아 보시겠습니까?</h4>
# 		<ul class="mn_list">
# 			{{#officeInfos}}
# 			<li class="mn_item">
# 				<div class="mn_head">
# 					<div class="mn_img">
# 						<img src="{{logo}}" alt="">
# 					</div>
# 					<div class="mn_name">{{officeName}}</div>
# 				</div>
# 				<div class="mn_body">
# 					<button type="button" class="mn_noti _ALL_OFFICES_NOTIFICATION_ITEM" data-oid="{{officeId}}" data-clk-add="notchnon" data-clk-remove="notchnoff">알림받기 사용함</button>
# 				</div>
# 			</li>
# 			{{/officeInfos}}
# 		</ul>
# 	</div>
# 	<div class="mn_btns">
# 		<button type="button" class="mn_btn _MODAL_LAYER_NEGATIVE" data-clk="{{nclk}}no">닫기</button>
# 		<button type="button" class="mn_btn as_em _MODAL_LAYER_POSITIVE _CHANNEL_BANNER_ITEM_NOTICE_COMPLETE" data-clk="{{nclk}}yes">완료</button>
# 	</div>
# </div>
# </script>
# <div id="_MODAL_COMMENT_FOLLOW_TUTORIAL" style="display: none;"></div>
# <script type="x-tmpl-mustache" class="_MODAL_COMMENT_FOLLOW_TUTORIAL_TEMPLATE">
# <div class="comment_follow_tutorial" role="dialog" aria-modal="true">
# 	<div class="comment_follow_tutorial_layer">
# 		<div class="comment_follow_tutorial_layer_dimmed"></div>
# 		<div class="comment_follow_tutorial_layer_container">
# 			<div class="comment_follow_tutorial_layer_content">
# 				<div class="comment_follow_tutorial_layer_item">
# 					<p class="{{className}}">{{text}}</p>
# 					<i class="comment_follow_tutorial_layer_closeicon"></i>
# 					<button type="button" class="comment_follow_tutorial_layer_close _MODAL_COMMENT_FOLLOW_TUTORIAL_CLOSE" data-clk="{{nclkPrefix}}tutclose">닫기</button>
# 				</div>
# 			</div>
# 		</div>
# 	</div>
# </div>
# </script>
# <div id="_TICKER_LAYER_FOR_NOTIFICATION" class="ticker" style="display: none;"></div>
# <script type="x-tmpl-mustache" class="_TICKER_LAYER_TEMPLATE_FOR_NOTIFICATION">
# {{#officeInfos}}
# <p class="t_inner"><em class="t_point">{{officeName}}</em> 언론사 알림이 설정되었습니다.</p>
# {{/officeInfos}}
# </script>
# <script src="https://static-nnews.pstatic.net/js/min/20230629/library.min.js"></script>
# <script src="https://static-nnews.pstatic.net/js/min/20230629/read.min.js"></script>
# <script>
# 	window.ntm = window.ntm || [];
# 	var ntmOption = {};
#
# 	if (ntmOption) {
#
# 		var section = {"id":"103","name":"생활"};
# 		var redirectSection = {"id":"103","name":"생활"};
#
# 		ntmOption["channelId"] = article.officeId;
#
# 		// 기타 또는 주요 섹션 이름
# 		var nilSendSectionName = "기타";
# 		var nilSendSectionId = "";
# 		if (/100|101|102|103|104|105|106|107/.test(section.id)) {
# 			nilSendSectionName = section.name;
# 			nilSendSectionId = section.id;
# 		}
#
# 		// 기사 타입
# 		var htArticleTypeName = { "0": "text", "1": "photo", "2": "tv" };
# 		var articleTypeName = htArticleTypeName[article.type] || "";
#
# 		ntmOption["hitType"] = "cv";
# 		ntmOption["eventCategory"] = "post_view";
# 		ntmOption["uri"] = "http://news.naver.com/main/read.nhn?oid=346&aid=0000062543";
# 		ntmOption["gdid"] = article.gdid;
# 		ntmOption["dimension1"] = encodeURIComponent(nilSendSectionName);
# 		ntmOption["dimension4"] = articleTypeName;
# 		ntmOption["optional2"] = nilSendSectionId;
#
# 		var journalistIdList = [];
#
# 		// 기자 목록
# 		$("._JOURNALIST_CARD ._JOURNALIST_ID").each(function (index, object) {
# 			var $this = $(object);
# 			var journalistId = $this.attr("data-journalistId");
#
# 			if (journalistId && journalistIdList.indexOf(journalistId) === -1) {
# 				journalistIdList.push(journalistId);
# 			}
# 		});
#
# 		if (journalistIdList.length > 0) {
# 			ntmOption["dimension3"] = journalistIdList.join("___");
# 		}
#
# 		if (location.href.match(/ntype=RANKING/)) {
# 			ntmOption["dimension5"] = "y";
# 		}
#
# 		if (service.sports) {
# 			ntmOption["dimension2"] = article.sectionInfo.secondSection + "." + article.sectionInfo.thirdSection;
# 		}
#
# 		var seriesComponentId = $("._VALID_SERIES").attr("data-component-id");
# 		ntmOption["dimension6"] = seriesComponentId;
#
# 		if (/[?|&]type=breakingnews(&|$)/.test(location.href) === true) {
# 			if (/(m\.naver\.com)|(media\.naver\.com)|(news\.naver\.com\/?$)|(www\.naver\.com)/.test(document.referrer) === true) {
# 				ntmOption["dimension7"] = "breaking";
# 			}
# 		}
#
# 		var ntmLeaveOption = $.extend({}, ntmOption);
# 		ntmLeaveOption["hitType"] = "event";
# 		ntmLeaveOption["eventCategory"] = "action";
# 		ntmLeaveOption["eventAction"] = "leave";
#
# 		if (/\/article\/comment\//.test(location.href) == false) {
# 			if (window.addEventListener) {
# 				window.addEventListener("load", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				}, false);
# 				window.addEventListener("unload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				}, false);
# 			} else if (window.attachEvent) {
# 				window.attachEvent("onload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 				});
# 				window.attachEvent("onunload", function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 				});
# 			} else {
# 				var fnOnUnload = window.onunload;
# 				window.onunload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmLeaveOption
# 					});
# 					if (fnOnUnload) {
# 						fnOnUnload();
# 					}
# 				};
#
# 				var fnOnload = window.onload;
# 				window.onload = function () {
# 					ntm.push({
# 						event: "nilSend",
# 						ni: ntmOption
# 					});
# 					if (fnOnload) {
# 						fnOnload();
# 					}
# 				};
# 			}
# 		}
# 	}
# </script>
# 		</div>
# 		<script>
# 			var eventType = "onpageshow" in window ? "pageshow" : "load";
# 			$(window).on(eventType, function() {
# 				lcs_do_gdid("88156f6f_000000000000000000062543");
#
# 				// ma 로그 전송
# 				var data = {
# 					"service": "news",
# 					"baseInfo": {
# 						"category": (/\/article\/comment\//.test(location.href) == true) ? "댓글" : "본문",
# 					},
# 					"extraInfo": {
# 						"articleId": article.articleId,
# 						"sectionId": article.sectionId,
# 						"officeId": article.officeId,
# 						"articleType": article.type
# 					}
# 				};
#
# 				if (typeof ma !== "undefined") {
# 					ma.init({
# 						api: "https://ma.news.naver.com/l",
# 						data: data,
# 						contentBodyEl: document.querySelector("._article_content"),
# 						contentBodyVideoWrapperSelector: "._VIDEO_AREA"
# 					});
# 				}
#
# 				if (window.matchMedia("(prefers-color-scheme)").media === "not all") {
# 					$("html").removeClass("DARK_THEME");
# 				}
# 			});
# 		</script>
# 	</body>
# </html>
#
# Content-Type: text/html; charset=utf-8
# x-content-type-options: nosniff
# x-xss-protection: 1; mode=block
# x-frame-options: DENY
# referrer-policy: unsafe-url
# Server: nfront
# Vary: Accept-Encoding
# Cache-Control: no-cache, no-store, must-revalidate
# Expires: Thu, 06 Jul 2023 08:05:24 GMT
# Date: Thu, 06 Jul 2023 08:05:24 GMT
# Transfer-Encoding: chunked
# Connection: close
# Connection: Transfer-Encoding
# Set-Cookie: N_SES=596141f4-806e-464a-ba3d-24fcc6515c67; Max-Age=1800; Path=/; Expires=Thu, 06 Jul 2023 08:35:24 GMT

# %%
url = "https://kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.xml?key=f5eef3421c602c6cb7ea224104795888&targetDt=20230705"
try:
    res = req.urlopen(url)
    contents = res.read().decode('utf-8')
except Exception as e:
    print(e)
else:
    with open("./movie.txt","w",encoding="utf-8") as f:
        f.write(contents)

# %%
from urllib.parse import urlencode

url ="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&"
param = {"query":"축구"}
url += urlencode(param)
try:
    res = req.urlopen(url)
    contents = res.read().decode('UTF-8')
except Exception as e:
    print(e)
else:
    print(res.info())
    print(contents)
# Out:
# Date: Thu, 06 Jul 2023 08:38:53 GMT
# Content-Type: text/html; charset=UTF-8
# Transfer-Encoding: chunked
# Connection: close
# Vary: Accept-Encoding
# Set-Cookie: page_uid=i6i9Fdp0JywsshleRDlssssst/0-437344; path=/; domain=.naver.com
# Set-Cookie: _naver_usersession_=LCOBvQgFzu9I9sduOxHW0g==; path=/; expires=Thu, 06-Jul-23 08:43:53 GMT; domain=.naver.com
# X-Frame-Options: SAMEORIGIN
# X-XSS-Protection: 1; report=/p/er/post/xss
# Cache-Control: no-cache, no-store, must-revalidate, max-age=0
# Pragma: no-cache
# Set-Cookie: nx_ssl=2; Domain=.naver.com; Path=/; Expires=Sat, 05-Aug-2023 08:38:53 GMT;
# Referrer-Policy: unsafe-url
# Vary: Accept-Encoding
# Server: nxg
# Accept-CH: Sec-CH-UA, Sec-CH-UA-Arch, Sec-CH-UA-Bitness, Sec-CH-UA-Full-Version-List, Sec-CH-UA-Mobile, Sec-CH-UA-Model, Sec-CH-UA-Platform, Sec-CH-UA-Platform-Version, Sec-CH-UA-WoW64
#
#
# <!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="축구 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'축구'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="'축구'의 네이버 통합검색 결과입니다."> <title>축구 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_230706.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_230629.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var _nx_js_load = (function () { var scrs = {} ; return function (script, callback) { scrs[script] = {} ; scrs[script].domscript = document.createElement('script'); scrs[script].domscript.src = script ; if (callback) scrs[script].callback = (callback instanceof Array) ? callback : [callback]; scrs[script].domscript.onloadDone = false; scrs[script].domscript.onload = function() { scrs[script].domscript.onloadDone = true; if (scrs[script].callback) { for (var i = 0; i < scrs[script].callback.length; i++) { scrs[script].callback[i]() ; } } scrs[script].domscript.onload = scrs[script].domscript.onreadystatechange = null; } ; scrs[script].domscript.onreadystatechange = function() { if ( ("loaded" === scrs[script].domscript.readyState || "complete" === scrs[script].domscript.readyState) && !scrs[script].domscript.onloadDone ) { scrs[script].domscript.onload(); } } ; document.getElementsByTagName('head')[0].appendChild(scrs[script].domscript); }; })() ; var nx_js_defer_load = (function() { var info = {} ; return function(scrname, callback, t) { var nx_load_once = (function() { return function(scrname) { if (info[scrname].t > 0) setTimeout(function() { _nx_js_load(scrname, info[scrname].callback) ; }, t) ; else _nx_js_load(scrname, info[scrname].callback) ; } ; })(); if (t < 0) t = 0 ; if (info[scrname]) { n = info[scrname].length; for (var i = 0; i < n; i++) { if (info[scrname][i] == callback) return ; } if (t < info[scrname].t) info[scrname].t = t ; } else { info[scrname] = {} ; info[scrname].callback = [] ; info[scrname].t = t ; jindo.$Fn(function() { nx_load_once(scrname) ; }).attach(window, "load") ; } info[scrname].callback.push(callback) ; }; })(); function nx_js_lazyload(scripts, onload, is_serial) { if (!(scripts instanceof Array)) { scripts = [scripts]; } if (is_serial) { function load_next() { if (scripts.length == 0) { onload(); return; } _nx_js_load( scripts.shift(), load_next ) ; } load_next(); } else { var load_check = function() { var num_js = scripts.length; return function() {  ...
# <span class="num">32명</span></div></a></div><div role="presentation" class="flick_bx"><a href="?query=%EC%B6%95%EA%B5%AC&where=influencer&x_influencer=%7B%22filters%22%3A%7B%22majorSubject%22%3A%22241109319040320%22%2C%22minorSubject%22%3A%22%22%2C%22gender%22%3A%22%22%2C%22generation%22%3A%22%22%2C%22channel%22%3A%22%22%7D%7D" role="tab" aria-selected="false" class="option" onclick="return goOtherCR(this,'a=ink_kis*f.maintheme&r=&i=&g=K_241109319040320&u='+urlencode(this.href))"><div class="thumb"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMTAyMDJfMTU0%2FMDAxNjEyMjYxNTQwMjA4.p3lnad6UYnYhKoKAXsvem_T9k_xav1tBdix0gOEGunIg.325ewGQ9Vcf6WdXu5b-kOqyY-GOnGRczgiqHqXadIMYg.PNG%2F%25ED%2582%25A4%25ED%2582%25B7_logo_%25EC%2582%25AC%25EA%25B0%2581%25ED%2598%2595_Light.png&type=f76_76" width="28" height="28" alt class="img" onerror="this.src='...',this.className='img bg_npimg'" data-img-alias="inf-img"></div><div class="name_area"><strong class="name">운동레저 전문블로거</strong>
# <span class="num">23명</span></div></a></div><div role="presentation" class="flick_bx"><a href="?query=%EC%B6%95%EA%B5%AC&where=influencer&x_influencer=%7B%22filters%22%3A%7B%22majorSubject%22%3A%22241109319048512%22%2C%22minorSubject%22%3A%22%22%2C%22gender%22%3A%22%22%2C%22generation%22%3A%22%22%2C%22channel%22%3A%22%22%7D%7D" role="tab" aria-selected="false" class="option" onclick="return goOtherCR(this,'a=ink_kis*f.maintheme&r=&i=&g=K_241109319048512&u='+urlencode(this.href))"><div class="thumb"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMDA1MjJfMjUw%2FMDAxNTkwMTA2OTcwMTI2.2Yzop7IwoISs6RGExx-YGzNuB2m67MVG2o3S437aZFQg.7mFmur0vgUuXIGY-WHjVccEJm1CItJVDhDi5jZfz_fUg.PNG%2F27.png&type=f76_76" width="28" height="28" alt class="img" onerror="this.src='...',this.className='img bg_npimg'" data-img-alias="inf-img"></div><div class="name_area"><strong class="name">운동레저 영상크리에이터</strong>
# <span class="num">3명</span></div></a></div><div role="presentation" class="flick_bx"><a href="?query=%EC%B6%95%EA%B5%AC&where=influencer&x_influencer=%7B%22filters%22%3A%7B%22majorSubject%22%3A%22241109331340608%22%2C%22minorSubject%22%3A%22%22%2C%22gender%22%3A%22%22%2C%22generation%22%3A%22%22%2C%22channel%22%3A%22%22%7D%7D" role="tab" aria-selected="false" class="option" onclick="return goOtherCR(this,'a=ink_kis*f.maintheme&r=&i=&g=K_241109331340608&u='+urlencode(this.href))"><div class="thumb"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMDEwMjNfMTc5%2FMDAxNjAzNDYzNzk4NzI3.4MDZN0GOOaGaD_LNortOkxYqjc3ab4D-IglhwEkrNy4g.cVNM6bJ6fu5YcP2O88_vRjcv6H_654myQ4l6YcSrTr0g.JPEG%2FACB568EF-1451-43D2-B107-F2E9B0BD4709.jpeg&type=f76_76" width="28" height="28" alt class="img" onerror="this.src='...',this.className='img bg_npimg'" data-img-alias="inf-img"></div><div class="name_area"><strong class="name">트레이너/강사</strong>
# <span class="num">2명</span></div></a></div><div role="presentation" class="flick_bx"><a href="?query=%EC%B6%95%EA%B5%AC&where=influencer&x_influencer=%7B%22filters%22%3A%7B%22majorSubject%22%3A%22241109331365184%22%2C%22minorSubject%22%3A%22%22%2C%22gender%22%3A%22%22%2C%22generation%22%3A%22%22%2C%22channel%22%3A%22%22%7D%7D" role="tab" aria-selected="false" class="option" onclick="return goOtherCR(this,'a=ink_kis*f.maintheme&r=&i=&g=K_241109331365184&u='+urlencode(this.href))"><div class="thumb"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMDA4MDlfMjA4%2FMDAxNTk2OTExMjM4NTE1.hhitM7ULhPBcCnoVShu0kFk2WYc5fldJPhdB6d5SgNgg.ZJj3dM_FokLJnoVF61Woz4IrB_sPTl0yojrVnZZ6WOUg.JPEG%2F%25EC%259D%25BC%25EC%2583%258115.jpg&type=f76_76" width="28" height="28" alt class="img" onerror="this.src='...',this.className='img bg_npimg'" data-img-alias="inf-img"></div><div class="name_area"><strong class="name">운동/레저 매거진에디터</strong>
# <span class="num">2명</span></div></a></div><div role="presentation" class="flick_bx"><a href="?query=%EC%B6%95%EA%B5%AC&where=influencer&x_influencer=%7B%22filters%22%3A%7B%22majorSubject%22%3A%22241109331381568%22%2C%22minorSubject%22%3A%22%22%2C%22gender%22%3A%22%22%2C%22generation%22%3A%22%22%2C%22channel%22%3A%22%22%7D%7D" role="tab" aria-selected="false" class="option" onclick="return goOtherCR(this,'a=ink_kis*f.maintheme&r=&i=&g=K_241109331381568&u='+urlencode(this.href))"><div class="thumb"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMDAyMTZfMjE3%2FMDAxNTgxODMyMjg3MDc4.z3iNehzTxtZjgJXKFfJvzI9LM7CDZqJPZERaQ_2O7y4g.BKAfIwenpNKTlbAQKzgT-_wiwuHqv_Gyw_88iOQ4cPMg.PNG%2Fsoccer-technica-1.png&type=f76_76" width="28" height="28" alt class="img" onerror="this.src='...',this.className='img bg_npimg'" data-img-alias="inf-img"></div><div class="name_area"><strong class="name">스포츠 칼럼니스트</strong>
# <span class="num">1명</span></div></a></div><div role="presentation" class="flick_bx"><a href="?query=%EC%B6%95%EA%B5%AC&where=influencer&x_influencer=%7B%22filters%22%3A%7B%22majorSubject%22%3A%22241109331393856%22%2C%22minorSubject%22%3A%22%22%2C%22gender%22%3A%22%22%2C%22generation%22%3A%22%22%2C%22channel%22%3A%22%22%7D%7D" role="tab" aria-selected="false" class="option" onclick="return goOtherCR(this,'a=ink_kis*f.maintheme&r=&i=&g=K_241109331393856&u='+urlencode(this.href))"><div class="thumb"><img src="..." data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMTAyMDFfMTA4%2FMDAxNjEyMTQ5ODYyNTg0.kzKZZ1C9SirOzrsXalBH904HGRE73TMo0ZbBuhqj0fQg.nUJRhBeVKWo_PFyZs_kDTG9KsahdDxblzHGSXIOBiNUg.JPEG%2FIMG_20190329_6.jpg&type=f76_76" width="28" height="28" alt class="img" onerror="this.src='...',this.className='img bg_npimg'" data-img-alias="inf-img"></div><div class="name_area"><strong class="name">스포츠 마케터</strong>
# <span class="num">1명</span></div></a></div></div><div class="api_btn_page type_tag"><div class="btn_prev _scroll_prev" style="display:none;"><a href="#" role="button" class="btn"><i class="spnew ico_arr">이전</i></a></div><div class="btn_next _scroll_next" style="display:none;"><a href="#" role="button" class="btn"><i class="spnew ico_arr">다음</i></a></div></div></div></div></div><div class="challenge_wrap"><ul class="keyword_challenge_list _inf_contents"><li class="keyword_bx _item _check_visible" data-myfeed-link="https://in.naver.com/myfeed?filterSpaceId=434422297816352&selectedSpaceId=434422297816352" data-space-id="434422297816352" data-alarm-name="피칸씨" data-containment data-list-index="0" data-fan-on-click-id="ink_kis*a.fanon" data-fan-off-click-id="ink_kis*a.fanoff"><div class="keyword_box_wrap api_ani_send"><div class="user_box"><a target="_blank" href="https://in.naver.com/pecan?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="user_thumb_wrap" onclick="return goOtherCR(this,'a=ink_kis*a.profile&r=1&i=a0209rl4_nblog_post_223142978440&u='+urlencode(this.href))"><svg class="badge_fan _fe_badge_fan" width="56" height="55" viewBox="0 0 56 55" fill="none" xmlns="http://www.w3.org/2000/svg" style="display:none;"><mask id="in59xl2vqa" fill="#fff"><path fill-rule="evenodd" clip-rule="evenodd" d="M27.5 55C42.688 55 55 42.688 55 27.5S42.688.0 27.5.0.0 12.312.0 27.5 12.312 55 27.5 55zm0-2.547c13.781.0 24.953-11.172 24.953-24.953.0-13.782-11.172-24.954-24.953-24.954-13.782.0-24.954 11.172-24.954 24.954.0 13.781 11.172 24.953 24.954 24.953z"/></mask><path class="fill" fill-rule="evenodd" clip-rule="evenodd" d="M27.5 55C42.688 55 55 42.688 55 27.5S42.688.0 27.5.0.0 12.312.0 27.5 12.312 55 27.5 55zm0-2.547c13.781.0 24.953-11.172 24.953-24.953.0-13.782-11.172-24.954-24.953-24.954-13.782.0-24.954 11.172-24.954 24.954.0 13.781 11.172 24.953 24.954 24.953z" fill="#f37a44"/><path d="M54.5 27.5c0 14.912-12.088 27-27 27v1c15.464.0 28-12.536 28-28h-1zm-27-27c14.912.0 27 12.088 27 27h1c0-15.464-12.536-28-28-28v1zm-27 27c0-14.912 12.088-27 27-27v-1c-15.464.0-28 12.536-28 28h1zm27 27c-14.912.0-27-12.088-27-27h-1c0 15.464 12.536 28 28 28v-1zm24.453-27c0 13.505-10.948 24.453-24.453 24.453v1c14.057.0 25.453-11.396 25.453-25.453h-1zM27.5 3.046c13.505.0 24.453 10.948 24.453 24.454h1c0-14.058-11.396-25.454-25.453-25.454v1zM3.046 27.5c0-13.506 10.948-24.454 24.454-24.454v-1C13.442 2.046 2.046 13.442 2.046 27.5h1zM27.5 51.953c-13.506.0-24.454-10.948-24.454-24.453h-1c0 14.057 11.396 25.453 25.454 25.453v-1z" fill="#000" fill-opacity=".08" mask="url(#in59xl2vqa)"/><circle class="fill" cx="47" cy="42" r="9" fill="#f37a44"/><circle cx="47" cy="42" r="8.75" stroke="#000" stroke-opacity=".1" stroke-width=".5"/><path fill-rule="evenodd" clip-rule="evenodd" d="M49.47 39.663a.557.557.0 11.788.788L46.5 44.21a.554.554.0 01-.155.11.557.557.0 01-.643-.105l-1.94-1.94a.557.557.0 11.789-.788l1.548 1.549 3.371-3.372z" fill="#fff"/></svg><div class="badge_rank _fe_badge_rank"><i class="spinf ico_rank1">금</i><i class="spinf ico_badge_gold"></i></div><div class="user_thumb"><img src="..." data-default-class="bg_npimg" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fhomebuilder-phinf.pstatic.net%2FMjAyMjExMjhfNTMg%2FMDAxNjY5NjA5MzA2ODc2.7TDLohzP47-jrAe0hEpdiQRV8JtYVihr9o50rCm5-kAg.leQdES_3Dg23Dhy3rUXExLK1bor5zMMBVJlSKwAVhD8g.JPEG%2F1669609306776_6A0D11B5-A4FB-474D-ADCD-E79388A7571B.jpeg&type=f96_96" width="45" height="45" alt class="img bg_npimg" onerror="this.src='...',this.className='img bg_npimg'" data-img-alias="inf-img"></div></a><div class="btn_area"><a href="#" role="button" class="btn_fan _fan_button" aria-pressed="false" data-home-url="https://in.naver.com/pecan?areacode=ink*a&query=%EC%B6%95%EA%B5%AC"><div class="base"><div class="container"><svg class="smile" width="16" height="16" viewBox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><g id="Page-1" stroke="none" stroke-width="1" fill="none" fill-rule="evenodd"><g id="smileSvg"><path class="circl ...
# <span class="etc">골프 전문</span>
# <span class="etc">팬 <span class="_fan_count">5,740</span></span></div></div><div class="my_keyword_area"><div class="my_type_overview"><div class="keyword_list"><span class="bx"><span class="keyword type_catch"><span class="icon_bx"><svg class="ico_prize" xmlns="http://www.w3.org/2000/svg" width="14" height="14" viewBox="0 0 14 14"><g fill="none" fill-rule="evenodd"><g class="fill" fill="#fff"><path d="M10 0c2.21.0 4 1.79 4 4v6c0 2.21-1.79 4-4 4H4c-2.21.0-4-1.79-4-4V4c0-2.21 1.79-4 4-4h6zM6.47 4.375H5.25v5.356h1.22v-.377c.238.271.58.447 1.035.483l.176.007c1.017.0 1.864-.842 1.939-1.96l.005-.161c0-1.143-.8-2.037-1.8-2.116l-.144-.005c-.484.0-.853.146-1.117.393l-.094.097V4.375zm.968 2.287c.566.0.987.356 1.04.934l.007.127c0 .608-.384 1.005-.928 1.055l-.12.005c-.607.0-1.047-.408-1.047-1.06.0-.609.384-1.005.928-1.055l.12-.006z" transform="translate(-1153 -1172) translate(178 230) translate(975 941) translate(0 1)"/></g></g></svg></span>블로그 이웃 8,500+</span></span>
# <span class="bx"><span class="keyword">야외활동 위주</span></span>
# <span class="bx"><span class="keyword">운동/레저 리뷰</span></span></div><div class="my_type_more"><a href="#" role="button" aria-expanded="false" aria-haspopup="true" class="btn_more _btn_expand" onclick="tCR('a=ink_kis*a.mymore&r=&i=&u=javascript')"><svg class="ico_fold_type" width="9" height="6" viewBox="0 0 9 6" fill="none" xmlns="http://www.w3.org/2000/svg"><path class="fill" fill-rule="evenodd" clip-rule="evenodd" d="M.22.22a.75.75.0 011.06.0l2.803 2.803L6.886.22a.75.75.0 111.061 1.06L4.083 5.144.22 1.28a.75.75.0 010-1.06z" fill="#f37a44"/></svg></a></div></div><div class="my_type_detail _area_expand" style="display: none;"><div class="dsc_bx"><div class="dsc_inner"><span class="tit">운동/레저 스타일</span><span class="txt">야외활동 위주</span></div><div class="dsc_inner"><span class="tit">창작 분야</span><span class="txt">운동/레저 리뷰</span></div></div><div class="detail_more"><a target="_blank" href="https://in.naver.com/pecan?search=true#COM-fe3a6c59-2043-4727-895a-3c650d2c9fa0" class="detail_more_link spinf_af" onclick="return goOtherCR(this,'a=ink_kis*a.mydetail&r=&i=&u='+urlencode(this.href))">자세히 보기</a></div></div></div></div></div><div class="detail_box"><div class="thumb_area"><div class="api_pcpg_wrap"><div class="api_flicking_wrap thumb_group_flick_wrap _scroll_target"><div class="flick_bx"><a target="_blank" href="https://in.naver.com/pecan/contents/internal/580798566731488?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223142978440" data-foryou-gdid="a0209rl4_nblog_post_223142978440" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=1&i=a0209rl4_nblog_post_223142978440&u='+urlencode(this.href))"><i class="spinf ico_blog_b">블로그</i><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMzA2MzBfMTI2%2FMDAxNjg4MDk3MTYzMTg1.oevbYRH9i5cLqLpuT4hewPYa70r_cLmpBbybYJ1eYIsg.t_gIRETbwCfer3fwX8T7PX8zprl0-WGapTsYbRFNjW4g.PNG.kja00710%2Fbatch_KakaoTalk_20230630_125007704_02.png%3Ftype%3Dw800&type=o372_180" width height="90" alt class="img bg_nimg _foryou_image_source" onerror="this.src='...',this.className='img bg_nimg'"></a></div><div class="flick_bx"><a target="_blank" href="https://in.naver.com/pecan/contents/internal/580798566731488?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223142978440" data-foryou-gdid="a0209rl4_nblog_post_223142978440" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=1&i=a0209rl4_nblog_post_223142978440&u='+urlencode(this.href))"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMzA2MzBfMjI4%2FMDAxNjg4MDk3MTU0Mjc2.Lm9HGVkBM6vzdAPNuu_DqBtaZ_2cfY4zwtYLGwYYYrog.SW8mHx5101zOR3SQzB10holpe1vDEQxgRhna0RqtyI8g.PNG.kja00710%2Fbatch_KakaoTalk_20230630_125007704.png%3Ftype%3Dw800&type=o372_180" width height="90" alt class="img bg_nimg _foryou_image_source" onerror="this.src='...',this.className='img bg_nimg'"></a></div><div class="flick_bx"><a target="_blank" href="https://in.naver.com/pecan/contents/internal/580798566731488?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223142978440" data-foryou-gdid="a0209rl4_nblog_post_223142978440" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=1&i=a0209rl4_nblog_post_223142978440&u='+urlencode(this.href))"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMzA2MzBfMTU5%2FMDAxNjg4MDk3MTU5MTEw.BabzCXwl-niKfqy4H3B7JEFfX1MR3UWGxME1_oS2_9Ag.FW7RMSxsJM0EiHYF5qHr0YQzSdahGwtJfkj_ZQ9jyYQg.PNG.kja00710%2Fbatch_KakaoTalk_20230630_125007704_01.png%3Ftype%3Dw800&type=o372_180" width height="90" alt class="img bg_nimg _foryou_image_source" onerror="this.src='...',this.className='img bg_nimg'"></a></div><div class="flick_bx"><a target="_blank" href="https://in.naver.com/pecan/contents/internal/580798566731488?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" c ...
# <a target="_blank" href="https://in.naver.com/pecan/contents/internal/580798566731488?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="dsc_link _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223142978440" data-foryou-gdid="a0209rl4_nblog_post_223142978440" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=1&i=a0209rl4_nblog_post_223142978440&u='+urlencode(this.href))"><p class="dsc">안녕하세요, 스포츠 인플루언서 피칸씨입니다. 한국 17세 이하 <mark>축구</mark>대표팀이 2023 아시아 <mark>축구</mark> 연맹 U17 아시안컵 4강에서 1:0으로 승리를 거둬 결승전에 진출하게 됐는데요. 오늘은 대한민국 <mark>축구</mark> 국가대표 일정인 U17...</p></a><span class="date">6일 전</span></div></div></div><div class="more_box"><a target="_blank" href="https://in.naver.com/pecan/challenge/keyword/253561223333665?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="spinf_af more_link" onclick="return goOtherCR(this,'a=ink_kis*a.nmore&r=1&i=&u='+urlencode(this.href))"><span class="name">피칸씨</span><span class="txt">의 참여 콘텐츠 10개 더보기</span></a></div></li><li class="keyword_bx _item _check_visible" data-myfeed-link="https://in.naver.com/myfeed?filterSpaceId=441827866556448&selectedSpaceId=441827866556448" data-space-id="441827866556448" data-alarm-name="보미" data-containment data-list-index="0" data-fan-on-click-id="ink_kis*a.fanon" data-fan-off-click-id="ink_kis*a.fanoff"><div class="keyword_box_wrap api_ani_send"><div class="user_box"><a target="_blank" href="https://in.naver.com/bomy?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="user_thumb_wrap" onclick="return goOtherCR(this,'a=ink_kis*a.profile&r=2&i=a0209rl4_nblog_post_223144337580&u='+urlencode(this.href))"><svg class="badge_fan _fe_badge_fan" width="56" height="55" viewBox="0 0 56 55" fill="none" xmlns="http://www.w3.org/2000/svg" style="display:none;"><mask id="in59xl2vqa" fill="#fff"><path fill-rule="evenodd" clip-rule="evenodd" d="M27.5 55C42.688 55 55 42.688 55 27.5S42.688.0 27.5.0.0 12.312.0 27.5 12.312 55 27.5 55zm0-2.547c13.781.0 24.953-11.172 24.953-24.953.0-13.782-11.172-24.954-24.953-24.954-13.782.0-24.954 11.172-24.954 24.954.0 13.781 11.172 24.953 24.954 24.953z"/></mask><path class="fill" fill-rule="evenodd" clip-rule="evenodd" d="M27.5 55C42.688 55 55 42.688 55 27.5S42.688.0 27.5.0.0 12.312.0 27.5 12.312 55 27.5 55zm0-2.547c13.781.0 24.953-11.172 24.953-24.953.0-13.782-11.172-24.954-24.953-24.954-13.782.0-24.954 11.172-24.954 24.954.0 13.781 11.172 24.953 24.954 24.953z" fill="#f37a44"/><path d="M54.5 27.5c0 14.912-12.088 27-27 27v1c15.464.0 28-12.536 28-28h-1zm-27-27c14.912.0 27 12.088 27 27h1c0-15.464-12.536-28-28-28v1zm-27 27c0-14.912 12.088-27 27-27v-1c-15.464.0-28 12.536-28 28h1zm27 27c-14.912.0-27-12.088-27-27h-1c0 15.464 12.536 28 28 28v-1zm24.453-27c0 13.505-10.948 24.453-24.453 24.453v1c14.057.0 25.453-11.396 25.453-25.453h-1zM27.5 3.046c13.505.0 24.453 10.948 24.453 24.454h1c0-14.058-11.396-25.454-25.453-25.454v1zM3.046 27.5c0-13.506 10.948-24.454 24.454-24.454v-1C13.442 2.046 2.046 13.442 2.046 27.5h1zM27.5 51.953c-13.506.0-24.454-10.948-24.454-24.453h-1c0 14.057 11.396 25.453 25.454 25.453v-1z" fill="#000" fill-opacity=".08" mask="url(#in59xl2vqa)"/><circle class="fill" cx="47" cy="42" r="9" fill="#f37a44"/><circle cx="47" cy="42" r="8.75" stroke="#000" stroke-opacity=".1" stroke-width=".5"/><path fill-rule="evenodd" clip-rule="evenodd" d="M49.47 39.663a.557.557.0 11.788.788L46.5 44.21a.554.554.0 01-.155.11.557.557.0 01-.643-.105l-1.94-1.94a.557.557.0 11.789-.788l1.548 1.549 3.371-3.372z" fill="#fff"/></svg><div class="badge_rank _fe_badge_rank"><i class="spinf ico_rank2">은</i><i class="spinf ico_badge_silver"></i></div><div class="user_thumb"><img src="..." data-default-class="bg_npimg" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fblogpfthumb-phinf.pstatic.net%2FMjAyMTA4MTJfMzMg%2FMDAxNjI4NzY3MjM0NTA4.NcJwRuCLK3stL6KKW9ceQv55D37B4XI95adv-F6wg70g.0SBlGdqle8LxrzA-j5-i1ZaKEyHCS5k2rlm6Lc8lYGAg.GIF.qhadldhaus98%2F1.gif&type=f96_96" width="45" height="45" alt class="img bg_npimg" onerror="this.src='...',this.className='img  ...
# <span class="etc">골프 전문</span>
# <span class="etc">팬 <span class="_fan_count">3,124</span></span></div></div><div class="my_keyword_area"><div class="my_type_overview"><div class="keyword_list"><span class="bx"><span class="keyword type_catch"><span class="icon_bx"><svg class="ico_prize" xmlns="http://www.w3.org/2000/svg" width="14" height="14" viewBox="0 0 14 14"><g fill="none" fill-rule="evenodd"><g class="fill" fill="#fff"><path d="M10 0c2.21.0 4 1.79 4 4v6c0 2.21-1.79 4-4 4H4c-2.21.0-4-1.79-4-4V4c0-2.21 1.79-4 4-4h6zM6.47 4.375H5.25v5.356h1.22v-.377c.238.271.58.447 1.035.483l.176.007c1.017.0 1.864-.842 1.939-1.96l.005-.161c0-1.143-.8-2.037-1.8-2.116l-.144-.005c-.484.0-.853.146-1.117.393l-.094.097V4.375zm.968 2.287c.566.0.987.356 1.04.934l.007.127c0 .608-.384 1.005-.928 1.055l-.12.005c-.607.0-1.047-.408-1.047-1.06.0-.609.384-1.005.928-1.055l.12-.006z" transform="translate(-1153 -1172) translate(178 230) translate(975 941) translate(0 1)"/></g></g></svg></span>블로그 이웃 1.4만+</span></span>
# <span class="bx"><span class="keyword">야외활동 위주</span></span>
# <span class="bx"><span class="keyword">운동/레저 리뷰</span></span></div><div class="my_type_more"><a href="#" role="button" aria-expanded="false" aria-haspopup="true" class="btn_more _btn_expand" onclick="tCR('a=ink_kis*a.mymore&r=&i=&u=javascript')"><svg class="ico_fold_type" width="9" height="6" viewBox="0 0 9 6" fill="none" xmlns="http://www.w3.org/2000/svg"><path class="fill" fill-rule="evenodd" clip-rule="evenodd" d="M.22.22a.75.75.0 011.06.0l2.803 2.803L6.886.22a.75.75.0 111.061 1.06L4.083 5.144.22 1.28a.75.75.0 010-1.06z" fill="#f37a44"/></svg></a></div></div><div class="my_type_detail _area_expand" style="display: none;"><div class="dsc_bx"><div class="dsc_inner"><span class="tit">운동/레저 스타일</span><span class="txt">야외활동 위주</span></div><div class="dsc_inner"><span class="tit">창작 분야</span><span class="txt">운동/레저 리뷰</span></div></div><div class="detail_more"><a target="_blank" href="https://in.naver.com/bomy?search=true#COM-1deb9857-8739-45fc-867b-cc021e6914f1" class="detail_more_link spinf_af" onclick="return goOtherCR(this,'a=ink_kis*a.mydetail&r=&i=&u='+urlencode(this.href))">자세히 보기</a></div></div></div></div></div><div class="detail_box"><div class="thumb_area"><div class="api_pcpg_wrap"><div class="api_flicking_wrap thumb_group_flick_wrap _scroll_target"><div class="flick_bx"><a target="_blank" href="https://in.naver.com/bomy/contents/internal/581349185600864?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223144337580" data-foryou-gdid="a0209rl4_nblog_post_223144337580" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=2&i=a0209rl4_nblog_post_223144337580&u='+urlencode(this.href))"><i class="spinf ico_blog_b">블로그</i><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMzA3MDJfMjk0%2FMDAxNjg4MjMwMTcyNzkx.8v51iAmqIhNsEzGlV4FUi4wmBUHgJtMPippe8zhZUxYg.IMbrZQYiyu80n0kBsMZB_8SH7OdCW9N0_OpNOvsqVPIg.PNG.qhadldhaus98%2Fimage.png%3Ftype%3Dw800&type=o372_180" width height="90" alt class="img bg_nimg _foryou_image_source" onerror="this.src='...',this.className='img bg_nimg'"></a></div><div class="flick_bx"><a target="_blank" href="https://in.naver.com/bomy/contents/internal/581349185600864?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223144337580" data-foryou-gdid="a0209rl4_nblog_post_223144337580" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=2&i=a0209rl4_nblog_post_223144337580&u='+urlencode(this.href))"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMzA3MDJfMTcx%2FMDAxNjg4MjMwNDg5NjAz.0vviaG9PQNBjtGQyt74Ppl3Dlx3t3yzbog0N1AsCtW8g.1nmThjD-wDPWJOQYzcBjQY5g8GTUrxhv2CLkIMTo1gcg.PNG.qhadldhaus98%2Fimage.png%3Ftype%3Dw800&type=o372_180" width height="90" alt class="img bg_nimg _foryou_image_source" onerror="this.src='...',this.className='img bg_nimg'"></a></div><div class="flick_bx"><a target="_blank" href="https://in.naver.com/bomy/contents/internal/581349185600864?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223144337580" data-foryou-gdid="a0209rl4_nblog_post_223144337580" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=2&i=a0209rl4_nblog_post_223144337580&u='+urlencode(this.href))"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMzA2MjlfMjI1%2FMDAxNjg4MDQwNjg2MDcz.8OYCvFVb_5_8AGVvMJLfGt26-ZY1-WlcGrfFfkdb5OEg.WqDr3RvIMvan3NFPuHP0_4Mr6A4SgsK5Te4fuy8kyJUg.PNG.qhadldhaus98%2Fimage.png%3Ftype%3Dw800&type=o372_180" width height="90" alt class="img bg_nimg _foryou_image_source" onerror="this.src='...',this.className='img bg_nimg'"></a></div><div class="flick_bx"><a target="_blank" href="https://in.naver.com/bomy/contents/internal/581349185600864?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_22314433 ...
# <a target="_blank" href="https://in.naver.com/bomy/contents/internal/581349185600864?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="dsc_link _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223144337580" data-foryou-gdid="a0209rl4_nblog_post_223144337580" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=2&i=a0209rl4_nblog_post_223144337580&u='+urlencode(this.href))"><p class="dsc">대한민국 국가대표 <mark>축구</mark> u17 아시안컵 일정 명단 결승 한일전 중계 드디어 7월2일 오후 9시 u17아시안컵 일정이 있습니다 바로바로 일본과의 한일전 결승전만을 남겨두고 있습니다. 아우 진짜 이 귀요미들을...</p></a><span class="date">5일 전</span></div></div></div><div class="more_box"><a target="_blank" href="https://in.naver.com/bomy/challenge/keyword/253561223333665?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="spinf_af more_link" onclick="return goOtherCR(this,'a=ink_kis*a.nmore&r=2&i=&u='+urlencode(this.href))"><span class="name">보미</span><span class="txt">의 참여 콘텐츠 26개 더보기</span></a></div></li><li class="keyword_bx _item _check_visible" data-myfeed-link="https://in.naver.com/myfeed?filterSpaceId=174504806239264&selectedSpaceId=174504806239264" data-space-id="174504806239264" data-alarm-name="생존홈트" data-containment data-list-index="0" data-fan-on-click-id="ink_kis*a.fanon" data-fan-off-click-id="ink_kis*a.fanoff"><div class="keyword_box_wrap api_ani_send"><div class="user_box"><a target="_blank" href="https://in.naver.com/nihaoyoga?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="user_thumb_wrap" onclick="return goOtherCR(this,'a=ink_kis*a.profile&r=3&i=a0209rl4_nblog_post_223142446553&u='+urlencode(this.href))"><svg class="badge_fan _fe_badge_fan" width="56" height="55" viewBox="0 0 56 55" fill="none" xmlns="http://www.w3.org/2000/svg" style="display:none;"><mask id="in59xl2vqa" fill="#fff"><path fill-rule="evenodd" clip-rule="evenodd" d="M27.5 55C42.688 55 55 42.688 55 27.5S42.688.0 27.5.0.0 12.312.0 27.5 12.312 55 27.5 55zm0-2.547c13.781.0 24.953-11.172 24.953-24.953.0-13.782-11.172-24.954-24.953-24.954-13.782.0-24.954 11.172-24.954 24.954.0 13.781 11.172 24.953 24.954 24.953z"/></mask><path class="fill" fill-rule="evenodd" clip-rule="evenodd" d="M27.5 55C42.688 55 55 42.688 55 27.5S42.688.0 27.5.0.0 12.312.0 27.5 12.312 55 27.5 55zm0-2.547c13.781.0 24.953-11.172 24.953-24.953.0-13.782-11.172-24.954-24.953-24.954-13.782.0-24.954 11.172-24.954 24.954.0 13.781 11.172 24.953 24.954 24.953z" fill="#f37a44"/><path d="M54.5 27.5c0 14.912-12.088 27-27 27v1c15.464.0 28-12.536 28-28h-1zm-27-27c14.912.0 27 12.088 27 27h1c0-15.464-12.536-28-28-28v1zm-27 27c0-14.912 12.088-27 27-27v-1c-15.464.0-28 12.536-28 28h1zm27 27c-14.912.0-27-12.088-27-27h-1c0 15.464 12.536 28 28 28v-1zm24.453-27c0 13.505-10.948 24.453-24.453 24.453v1c14.057.0 25.453-11.396 25.453-25.453h-1zM27.5 3.046c13.505.0 24.453 10.948 24.453 24.454h1c0-14.058-11.396-25.454-25.453-25.454v1zM3.046 27.5c0-13.506 10.948-24.454 24.454-24.454v-1C13.442 2.046 2.046 13.442 2.046 27.5h1zM27.5 51.953c-13.506.0-24.454-10.948-24.454-24.453h-1c0 14.057 11.396 25.453 25.454 25.453v-1z" fill="#000" fill-opacity=".08" mask="url(#in59xl2vqa)"/><circle class="fill" cx="47" cy="42" r="9" fill="#f37a44"/><circle cx="47" cy="42" r="8.75" stroke="#000" stroke-opacity=".1" stroke-width=".5"/><path fill-rule="evenodd" clip-rule="evenodd" d="M49.47 39.663a.557.557.0 11.788.788L46.5 44.21a.554.554.0 01-.155.11.557.557.0 01-.643-.105l-1.94-1.94a.557.557.0 11.789-.788l1.548 1.549 3.371-3.372z" fill="#fff"/></svg><div class="badge_rank _fe_badge_rank"><i class="spinf ico_rank3">동</i><i class="spinf ico_badge_bronze"></i></div><div class="user_thumb"><img src="..." data-default-class="bg_npimg" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fblogpfthumb-phinf.pstatic.net%2FMjAxNzA4MDVfMjYg%2FMDAxNTAxODg5NTYyNDgz.HwqdqRPWmhxB1SeiBEMkns-jBCvSZ-NPfHMRavZCttEg.wg4s9xzw6QgLuQMWrQHYA4rmLWe6GmsjczSaDpWw10Ug.GIF.nihaoyoga%2FprofileImage.gif&type=f96_96" width="45" height="45" alt class="img bg_npimg" onerror="this.src='...',this.className='img bg_npimg'" data-img-alia ...
# <span class="etc">요가 전문</span>
# <span class="etc">팬 <span class="_fan_count">7,722</span></span></div></div><div class="my_keyword_area"><div class="my_type_overview"><div class="keyword_list"><span class="bx"><span class="keyword type_catch"><span class="icon_bx"><svg class="ico_prize" xmlns="http://www.w3.org/2000/svg" width="14" height="14" viewBox="0 0 14 14"><g fill="none" fill-rule="evenodd"><g class="fill" fill="#fff"><path d="M7.29 1.75c.997.007 4.258.048 5.18.313.602.172 1.076.68 1.237 1.326.26 1.035.29 3.064.293 3.519v.183c-.004.455-.034 2.485-.293 3.52-.16.645-.635 1.153-1.238 1.326-.92.264-4.182.306-5.178.312h-.183l-.06.001H6.89l-.182-.001c-.997-.006-4.258-.048-5.18-.312-.602-.173-1.076-.681-1.237-1.327C.032 9.576.002 7.546-.001 7.091v-.183c.003-.455.033-2.484.292-3.52.16-.645.635-1.153 1.238-1.325.921-.265 4.182-.306 5.179-.313zm-1.603 3.5v3.5L9.187 7l-3.5-1.75z" transform="translate(-1153 -1282) translate(178 230) translate(975 941) translate(0 111)"/></g></g></svg></span>유튜브 구독 1만+</span></span>
# <span class="bx"><span class="keyword">홈트레이닝 위주</span></span>
# <span class="bx"><span class="keyword">전문지식</span></span></div><div class="my_type_more"><a href="#" role="button" aria-expanded="false" aria-haspopup="true" class="btn_more _btn_expand" onclick="tCR('a=ink_kis*a.mymore&r=&i=&u=javascript')"><svg class="ico_fold_type" width="9" height="6" viewBox="0 0 9 6" fill="none" xmlns="http://www.w3.org/2000/svg"><path class="fill" fill-rule="evenodd" clip-rule="evenodd" d="M.22.22a.75.75.0 011.06.0l2.803 2.803L6.886.22a.75.75.0 111.061 1.06L4.083 5.144.22 1.28a.75.75.0 010-1.06z" fill="#f37a44"/></svg></a></div></div><div class="my_type_detail _area_expand" style="display: none;"><div class="dsc_bx"><div class="dsc_inner"><span class="tit">운동/레저 스타일</span><span class="txt">홈트레이닝 위주</span></div><div class="dsc_inner"><span class="tit">창작 분야</span><span class="txt">전문지식</span></div></div><div class="detail_more"><a target="_blank" href="https://in.naver.com/nihaoyoga?search=true#COM-263a7936-e75b-4289-b022-bb15fab1af55" class="detail_more_link spinf_af" onclick="return goOtherCR(this,'a=ink_kis*a.mydetail&r=&i=&u='+urlencode(this.href))">자세히 보기</a></div></div></div></div></div><div class="detail_box"><div class="thumb_area"><div class="api_pcpg_wrap"><div class="api_flicking_wrap thumb_group_flick_wrap _scroll_target"><div class="flick_bx"><a target="_blank" href="https://in.naver.com/nihaoyoga/contents/internal/580563623853984?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223142446553" data-foryou-gdid="a0209rl4_nblog_post_223142446553" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=3&i=a0209rl4_nblog_post_223142446553&u='+urlencode(this.href))"><i class="spinf ico_blog_b">블로그</i><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMzA2MjlfNTIg%2FMDAxNjg4MDM5ODIzNjM4.RZ-7m9H53Hwj5ALzS1MRbO-1SUyCVFQyQbXn77u9p2Ig.RzRYfSmfx2eVwL8aBah3Ih3qrBj4e2EBwH_FdN15tXIg.JPEG.nihaoyoga%2FIMG_9979.JPG%3Ftype%3Dw800&type=o372_180" width height="90" alt class="img bg_nimg _foryou_image_source" onerror="this.src='...',this.className='img bg_nimg'"></a></div><div class="flick_bx"><a target="_blank" href="https://in.naver.com/nihaoyoga/contents/internal/580563623853984?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223142446553" data-foryou-gdid="a0209rl4_nblog_post_223142446553" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=3&i=a0209rl4_nblog_post_223142446553&u='+urlencode(this.href))"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMzA2MjlfMjky%2FMDAxNjg4MDM4NDY0ODY5.nUY3fnQLcv56FLvvtOAb9KfuSKVxO2Nj310l85C-LK0g.f-7GB3G0u8Yy1100Tn7mWyTWrlyo4uVFHpYCkgm7CUIg.PNG.nihaoyoga%2Fimage.png%3Ftype%3Dw800&type=o372_180" width height="90" alt class="img bg_nimg _foryou_image_source" onerror="this.src='...',this.className='img bg_nimg'"></a></div><div class="flick_bx"><a target="_blank" href="https://in.naver.com/nihaoyoga/contents/internal/580563623853984?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223142446553" data-foryou-gdid="a0209rl4_nblog_post_223142446553" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=3&i=a0209rl4_nblog_post_223142446553&u='+urlencode(this.href))"><img src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmblogthumb-phinf.pstatic.net%2FMjAyMzA2MjlfMTUw%2FMDAxNjg4MDM4Njg2MDkw.4uDaUiOV21_JkAhp2XgYzxG4GL87ojrFY_vUBO0b5nMg.TwjG3tyFjhMGJ5dM5vsDJpcLEFVKcQVTX23MjLtk694g.PNG.nihaoyoga%2Fimage.png%3Ftype%3Dw800&type=o372_180" width height="90" alt class="img bg_nimg _foryou_image_source" onerror="this.src='...',this.className='img bg_nimg'"></a></div><div class="flick_bx"><a target="_blank" href="https://in.naver.com/nihaoyoga/contents/internal/580563623853984?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="thumb _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_ ...
# <a target="_blank" href="https://in.naver.com/nihaoyoga/contents/internal/580563623853984?areacode=ink*a&query=%EC%B6%95%EA%B5%AC" class="dsc_link _cross_trigger _foryou_trigger" data-cr-gdid="a0209rl4_nblog_post_223142446553" data-foryou-gdid="a0209rl4_nblog_post_223142446553" onclick="return goOtherCR(this,'a=ink_kis*a.blog&r=3&i=a0209rl4_nblog_post_223142446553&u='+urlencode(this.href))"><p class="dsc">Here We Go 떳습니다 김민재 선수 분데스리가 바이에른 뮌헨 이적 거의 확정이네요 !! 이번에 이적 하게 되면 FIFA 연대기여금 으로 김민재 선수가 거쳤던 학교들 수원공고 에서는 12억 6천만원 가야 초등학교 는 약...</p></a><span class="date">7일 전</span></div></div></div><div class="more_box"><a target="_blank" href="https://in.naver.com/nihaoyoga/topic/580606662975264?areacode=ink.topic" class="spinf_af more_link type_topic" onclick="return goOtherCR(this,'a=ink_kis*a.topic&r=3&i=&u='+urlencode(this.href))"><span class="thumb"><img src="..." data-img-alias="inf-img" data-default-class="bg_nimg" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Finfluencer-phinf.pstatic.net%2FMjAyMzA2MjlfMjYg%2FMDAxNjg4MDQyNTI0MTc3.z2_KFiy-UytvBk379WS2U59bFWpCJADg11JuG0HNC8Ug._eEV85aULAl_HqY8iM09cC1aidiIkWBY8B9OD9k8pukg.PNG%2Fe664.png&type=f80_80" width="22" height="22" alt class="img" onerror="this.src='...',this.className='img bg_nimg'"></span><span class="txt">이 콘텐츠가 포함된 큐레이션 바로가기</span></a></div></li></ul></div></div><div class="api_more_wrap"><a href="?query=%EC%B6%95%EA%B5%AC&sm=tab_nmr&where=influencer" class="api_more" onclick="return goOtherCR(this,'a=ink_kis.more&r=&i=&u='+urlencode(this.href))">인플루언서 더보기<i class="spnew ico_arr"></i></a></div></div><div class="api_subject_bx _foryou_content type_apart" style="display:none;"></div></section><section class="sc_new sp_influencer type_nogap _fe_influencer_popup_section"><div class="ly_popup type_fan _popup_layer" style="display: none;"><div class="popup_alarm type_off _section_fan_success" style="display: none;"><div class="tit"><div class="name_wrap"><div class="name_bx"><div class="name _name"></div><div class="txt">님의 팬이 되었습니다!</div></div></div><div class="desc"><div class="name_bx"><div class="txt">검색 결과에서</div><div class="name _name"></div><div class="txt">님의 콘텐츠가 우선적으로 보일 수 있습니다.</div></div></div><div class="desc">팬 한 인플루언서의 콘텐츠는 나의 피드에서 모아볼 수 있어요.</div></div><div class="fan_btn_area"><div class="fan_btn_inner"><div class="btn_bx"><strong class="tit_sub">네이버 알림</strong>
# <a href="#" class="btn_option _button_toggle_alarm" role="button" aria-pressed="false"><i class="spinf ico_alarm_off">OFF</i>
# <i class="spinf ico_alarm_on">ON</i></a></div><a href="#" class="btn_item spinf_af ico_fan_arr _fe_my_feed">나의 피드 바로가기</a></div></div><a href="#" class="popup_close _button_close"><span class="spinf ico_info_close">닫기</span></a></div><div class="popup_alarm type_on _section_fan_info" style="display: none;"><div class="tit"><div class="name_wrap"><div class="name_bx"><div class="name _name"></div><div class="txt">님의 팬입니다!</div></div></div><div class="desc"><div class="name_bx"><div class="txt">검색 결과에서</div><div class="name _name"></div><div class="txt">님의 콘텐츠가 우선적으로 보일 수 있습니다.</div></div></div><div class="desc">팬 한 인플루언서의 콘텐츠는 나의 피드에서 모아볼 수 있어요.</div></div><div class="fan_btn_area"><div class="fan_btn_inner"><div class="btn_bx"><strong class="tit_sub">네이버 알림</strong>
# <a href="#" class="btn_option _button_toggle_alarm" role="button" aria-pressed="false"><i class="spinf ico_alarm_off">OFF</i>
# <i class="spinf ico_alarm_on">ON</i></a></div><a href="#" class="btn_item spinf_af ico_fan_arr _fe_my_feed">나의 피드 바로가기</a>
# <a href="#" class="btn_item btn_cancel _button_unsubscribe">팬하기 취소</a></div></div><a href="#" class="popup_close _button_close"><span class="spinf ico_info_close">닫기</span></a></div></div><div class="api_popup_capcha _fe_influencer_captcha_layer" style="display: none;"><div class="popup_capcha _fe_influencer_captcha_root"><p class="dsc_area"><strong class="tit">자동 팬하기를 방지하기 위해 보안 절차를 거치고 있습니다.</strong>
# <em class="txt">아래 문자를 보이는 대로 입력해주세요.</em></p><div class="code_area _fe_influencer_captcha_code_area"><div class="code_bx"><img src width="200" height="91" class="img _fe_influencer_captcha_code_image"><div class="guide"><i class="spnew ico_capcha_voice2"></i>
# <em class="txt">음성으로 안내되고 있습니다<br>시작음 3회 반복 후 재생</em></div></div><div class="btn_bx"><a href="#" class="btn_refresh _fe_influencer_captcha_code_refresh_button" onclick="tCR('a=ink_kis.cabre&r=&i=&u=javascript')"><i class="spnew ico_capcha_refresh">새로고침</i></a>
# <a href="#" class="btn_voice _fe_influencer_captcha_code_voice_button" onclick="tCR('a=ink_kis.cabvoice&r=&i=&u=javascript')"><i class="spnew ico_capcha_voice">음성으로 듣기</i></a>
# <a href="#" class="btn_image _fe_influencer_captcha_code_image_button" onclick="tCR('a=ink_kis.cabimg&r=&i=&u=javascript')"><i class="spnew ico_capcha_img">이미지로 보기</i></a></div></div><div class="input_area _fe_influencer_captcha_input_area"><span class="input_inner"><input placeholder="자동입력방지문자" class="input_code _fe_influencer_captcha_input_code"></span>
# <button class="btn_submit _fe_influencer_captcha_input_submit_button" onclick="tCR('a=ink_kis.cabin&r=&i=&u=javascript')">확인</button>
# <span class="etc _fe_influencer_captcha_input_etc" style="display: none">다시 입력해주세요</span></div><a href="#" class="popup_close _fe_influencer_captcha_input_close_button" onclick="tCR('a=ink_kis.cabclose&r=&i=&u=javascript')"><span class="spnew ico_info_close">닫기</span></a></div></div></section><section class="sc_new sp_influencer type_nogap _fe_influencer_toast_section"><div class="api_modal_toast _fe_influencer_toast_root" style="display: none;"><a href="javascript:;" class="btn_toast spnew_af disabled"><div class="dsc_area"><em class="dsc">더이상 <strong class="name _fe_influencer_toast_name"></strong>님의 팬이 아닙니다.</em><div class="dsc_sub">이제 알림을 받지 않습니다.</div></div></a></div></section><script>naver.common.imageLazyLoader.onLoad(naver.common.LazySrc.Handler.create({"inf-img":function(a){var d=a.prop('src'),c=a.attr("data-default-class"),b,e,f;if(c&&d.toString().indexOf("data:image")===-1&&a.removeClass(c),b=a.closest("._influencer_thumb"),b.length===0)return;e=b.height()/b.width(),f=a.get(0).naturalHeight/a.get(0).naturalWidth,e>f&&b.add("type_horizontal")}})),function(){var a=function(){window.require.config({context:"ugc",paths:{InfluencerPortalPC:"https://ssl.pstatic.net/sstatic/fe/sfe/ugc/influencer-pc/InfluencerPortalPC_230309.js".replace(/\.js$/,"")}})(["InfluencerPortalPC"],function(b){var c=document.getElementById("_section_influencer"),d=["pc","portal"],a=new b({store:{isEnd:!0},commonUI:{url:{homeSubscribeUrl:"https://gw.in.naver.com/home/api/v3/spaces/{=spaceId}/subscribes",homeUnsubscribeUrl:"https://gw.in.naver.com/home/api/v3/spaces/{=spaceId}/unsubscribes",homeMySubscribes:"https://gw.in.naver.com/delivery/api/v1/subscribes?spaceIds=",homeStatistics:"https://gw.in.naver.com/delivery/api/v1/space-statistics?spaceIds=",notiSubscribeSettingUrl:"https://gw.in.naver.com/notification/api/v1/spaces/{=spaceId}/subscribe-notification-setting",notiMySubscribeUrl:"https://gw.in.naver.com/notification/api/v1/spaces/{=spaceId}/my-subscribe-notification-setting",loginUrl:"https://nid.naver.com/nidlogin.login?svctype=262144&url=",imageCaptchaUrl:"https://captcha.nid.naver.com/nhncaptchav4.gif?key={=key}&{=timestamp}",voiceCaptchaUrl:"https://soundcaptcha.nid.naver.com/soundCaptcha.wav?key={=key}&replay={=replay}",captchaConfirmUrl:"https://gw.in.naver.com/identity-access/api/v1/captcha",captchaChangeUrl:"https://gw.in.naver.com/identity-access/api/v1/captcha?type={=type}&expireKey={=expireKey}&expireType={=expireType}",captchaRefreshUrl:"https://gw.in.naver.com/identity-access/api/v1/refresh-captcha?key={=key}&type={=type}",talktalkUrl:"https://gw.in.naver.com/home/api/v1/spaces/{=spaceId}/talktalk-url",errorRedirectUrl:"",lottieUrl:"https://ssl.pstatic.net/sstatic/au/m/influencer/asset/lottie.min.js"}},contents:{listIndex:0},dimensions:d,forYouConfig:{url:"https://s.search.naver.com/p/influencer/api/v1/airs",params:{where:"api",q:"축구",q_gdid:"",prev_clicked_gdids:"",search_result_gdids:"",abt:"",area:""},areaType:{keywordChallenge:"ink_kis*n",result:"ink_kis*N"},displayPosition:"collection",persistId:"_fe_inf_foryou_clicked_gdid",storage:{key:"_fe_inf_foryou_prev_clicked_gdids",duration:15*60*1e3,count:10},countForSRG:5}});a.on({"change-fan":function(a){tCR('a='+a.clickId+'&r=&i=&u=javascript')},"change-alarm":function(a){a.isAlarmOn?tCR('a=ink_kis.alimon&r=&i=&u=javascript'):tCR('a=ink_kis.alimoff&r=&i=&u=javascript')},crossDisplay:function(c){for(var b=(c.$collection.attr("data-cr-item")||"").split("|").filter(function(a){return!!a}),a=0;a<b.length;++a)tCR("a="+b[a])},"show-foryou":function(a){a.length&&window.naver&&window.naver.common&&window.naver.common.responsiveLog&&window.naver.common.responsiveLog.send&&window.naver.common.responsiveLog.send(a)}}),a.mount(c)})},b="https://ssl.pstatic.net/sstatic/au/module/requirejs/require-2.3.5.js";nhn.common.load_js(window.require?null:b,a,!0,150)}()</script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_nreview_220929.css"> <section clas ...
# <a target="_blank" href="https://keep.naver.com/" class="spnew_af item item_quick" onclick='goOtherCR(this,"a=web_gen.kep&r=0&i=a00000fa_89b6431035f194071d350bdc&u="+urlencode(this.href))'>Keep 바로가기</a></div></div><div class="total_source_group"><div class="total_source"><div class="source_box"><a target="_blank" href="https://namu.wiki/w/%EC%B6%95%EA%B5%AC" class="thumb" onclick='goOtherCR(this,"a=web_gen*w.link&r=0&i=a00000fa_89b6431035f194071d350bdc&u="+urlencode(this.href))'><img src="https://search.pstatic.net/sunny?src=https%3A%2F%2Fnamu.wiki%2Ffavicon-192.png&type=f30_30_png_expire24" width="15" height="15" alt></a>
# ...
#           </a>
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=6V1GgRgO3icWYbYGqXZVWP///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000240266266&amp;d=&#39; + urlencode(&#39;http://www.coupang.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#
#                 <span class="lnk_tit">쿠팡 축구 구매</span><span class="lnk_tit">후기 128개 돌파!</span>
#
#
#             </a>
#             <div class="url_area">
#               <span class="ico_nad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=6V1GgRgO3icWYbYGqXZVWP///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000240266266&amp;d=&#39;+urlencode(&#39;http://www.coupang.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">www.coupang.com</a>
#             </div>
#             <div class="desc_area">
#
#               <a href="https://adcr.naver.com/adcr?x=6V1GgRgO3icWYbYGqXZVWP///w==..." class="link_desc" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=2&amp;i=nad-a001-01-000000240266266&amp;d=&#39; + urlencode(&#39;http://www.coupang.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">씨에스소울 <strong class='hl'>축구</strong> 풋살 신가드 정강이 보호대</a>
#
#             </div>
#
#
#             <ul class="lst_price">
#
#                 <li class="item">
#                   <a href="https://adcr.naver.com/adcr?x=A7oKRM8/Qk0Ego14zanb6P///w==..." class="link"
#                      target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.pricelink1&amp;r=2&amp;i=nad-a001-01-000000240266266&amp;d=&#39;+urlencode(&#39;http://www.coupang.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <span class="price">7,690원</span>
#                     <div class="txt">
#                       <span class="txt_inner">33%할인 로켓배송</span>
#                     </div>
#                   </a>
#                 </li>
#
#             </ul>
#
#
#
#           </div>
#         </li>
#         <li class="lst type_more      "
#             onmouseover="jindo.$Element(this).addClass('ad_hover');"
#             onmouseout="jindo.$Element(this).removeClass('ad_hover');" num="2">
#
#           <div class="inner">
#             <a href="https://adcr.naver.com/adcr?x=/TVk0iOcGD+mu4SVVJWSMv///w==...&amp;p=0"
#                target="_blank"
#                class="lnk_head" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000053281287&amp;d=&#39; + urlencode(&#39;http://acetoto.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#
#
#                 <span class="lnk_tit">도시락 토토 !</span>
#
#             </a>
#             <div class="url_area">
#               <span class="ico_nad_mark">광고</span>
#
#               <a href="https://adcr.naver.com/adcr?x=/TVk0iOcGD+mu4SVVJWSMv///w==...&amp;p=1"
#                  class="lnk_url" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000053281287&amp;d=&#39;+urlencode(&#39;http://acetoto.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">acetoto.com</a>
#             </div>
#             <div class="desc_area">
#
#               <a href="https://adcr.naver.com/adcr?x=/TVk0iOcGD+mu4SVVJWSMv///w==..." class="link_desc" target="_blank"
#                  onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=3&amp;i=nad-a001-01-000000053281287&amp;d=&#39; + urlencode(&#39;http://acetoto.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">베트맨토토, 전 경기 무료분석 공유카페, 따뜻한 도시락토토에서 함께!</a>
#
#             </div>
#
#
#
#
#
#
#           </div>
#         </li>
#       </ul>
#       <div class="section_more">
#         <a class="go_site"
#            target="_blank" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%B6%95%EA%B5%AC&amp;referenceId=i6i9Fdp0JywsshleRDlssssst%2F0-437344" onclick="return goOtherCR(this, &#39;a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u=&#39;+urlencode(this.href));">
#           더보기<i class="icon_arrow sp_nad"></i></a>
#       </div>
#     </div>
#     <a class="nad_banner" href="https://help.pay.naver.com/faq/alias/powerad01.help"
#        onclick="return goOtherCR(this, 'a=mib_pwl.banner&r=0&i=mib_pwlbanner&u='+urlencode(this.href));" target="_blank">
#       <span class="sp_nad ico_npay">네이버페이</span>파워링크에서 네이버페이로 결제하면 추가 적립
#     </a>
#
#   </div>
#
#   <script type="text/javascript">
#       (function() {
#           var createPlaceImageConveyer = function() {
#               var prev = document.getElementById("_place_prev_button");
#               var next = document.getElementById("_place_next_button");
#               if (prev == null || next == null) {
#                   return;
#               }
#               prev.style.display = "none";
#               var require = window.require.config({
#                   context: "impression_neo_place_extension",
#                   paths: {
#                       "egjsConveyer": "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220822/js/egjs-conveyer.min.k253dc24"
#                   }
#               });
#               require(["egjsConveyer"], function(egjsConveyer) {
#                   var conveyer = new egjsConveyer("#place_flicking", { autoInit: false, preventClickOnDrag: true});
#
#
#                   conveyer.subscribe("isReachStart", function(isReachStart) {
#                       prev.style.display = isReachStart ? "none" : "block";
#                   });
#
#                   conveyer.subscribe("isReachEnd", function(isReachEnd) {
#                       next.style.display = isReachEnd ? "none" : "block";
#                   });
#                   conveyer.init();
#
#                   if (!conveyer.isReachEnd) {
#                       next.style.display = "block";
#                   }
#
#                   prev.addEventListener("click", function() {
#                       conveyer.scrollIntoView("start", {
#                           align: "end",
#                           duration: 500,
#                           excludeStand: true,
#                       });
#                   });
#                   next.addEventListener("click", function() {
#                       conveyer.scrollIntoView("end", {
#                           align: "start",
#                           duration: 500,
#                           excludeStand: true,
#                       });
#                   });
#               });
#           };
#           nhn.common.load_js(null, createPlaceImageConveyer, true, 150);
#       })();
#   </script>
#
#
#
#
# <link rel="stylesheet" href="https://ssl.pstatic.net/adimg3.search/imp/nx/libs/egjs-flicking/4.4.2/flicking-inline.css" />
# <link rel="stylesheet" href="https://ssl.pstatic.net/adimg3.search/imp/nx/libs/egjs-flicking-plugins/20220228/flicking-plugins.min.css">
#
# <div class="ad_section section" id="_power_link_together_section" style="display: none;" data-responsive-json="{&quot;aq&quot;:0,&quot;ssc&quot;:&quot;tab.nx.all&quot;,&quot;apiUrl&quot;:&quot;https://external-api.impression-neo.naver.com/api/v1/powerLinkForYou/responsive/ads/search&quot;,&quot;requestId&quot;:&quot;i6i9Fdp0JywsshleRDlssssst/0-437344&quot;,&quot;query&quot;:&quot;축구&quot;,&quot;channel&quot;:&quot;naver.search.pc.pl.responsive&quot;,&quot;sm&quot;:&quot;top_hty&quot;,&quot;adCreativeIds&quot;:[&quot;nad-a001-01-000000239973698&quot;,&quot;nad-a001-01-000000240266266&quot;,&quot;nad-a001-01-000000053281287&quot;]}">
#     <div id="responsive_root"></div>
#     <div class="lst_type_v2" id="map_layer" style="display: none;">
#         <div class="lst">
#           <div class="ly_map _preview_layer" style="top: 0px !important;" id="_preview_layer">
#             <h4 class="sp_ad_map m_tit">위치 미리보기</h4>
#             <div id="map" class="map_area" width="375" height="312">
#               <div id="map" style="position: relative; overflow: hidden; background: url('https://ssl.pstatic.net/static/maps/mantle/1x/pattern_1.png') 0px 0px repeat transparent; width: 375px; height: 312px;"></div>
#               <span class="bd"><span class="bd_top"></span><span class="bd_rgt"></span><span class="bd_btm"></span><span class="bd_lft"></span></span>
#             </div>
#             <div class="tit_area">
#               <div class="tit_sec">
#                   <h4 class="tit">
#                       <a target="_blank" id="preview_headline" href="" onclick="" class="txt"></a>
#                       <a target="_blank" id="preview_find_map" href="" onclick="" class="sp_ad_map ico_find_road">길찾기</a>
#                   </h4>
#                   <div class="m_url">
#                       <a target="_blank" id="preview_display_url" href="" onclick="" class="txt"></a>
#                   </div>
#               </div>
#               <div class="info_sec">
#                   <div class="address">
#                       <p class="txt" id="preveiw_number_address"></p>
#                       <p class="txt">
#                           <span class="sp_ad_map ico_road_name"><span class="blind">도로명 주소</span></span> <span id="preview_road_address"></span>
#                       </p>
#                   </div>
#                   <div class="dsc"></div>
#               </div>
#           </div>
#             <a href="javascript:;" class="sp_ad_mall btn_clse" id="map_btn_clse" title="미리보기 닫기">닫기</a>
#             </div>
#         </div>
#       </div>
# </div>
#
#
#   <div class="api_sc_page_wrap"><div class="sc_page"><a role="button" class="btn_prev" aria-disabled="true"><i class="spnew ico_page_arr">이전</i></a><div class="sc_page_inner"><a href="?nso=&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&where=nexearch" onclick='goOtherCR(this,"a=pag.pag&r=1&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="true">1</a>
# <a href="?nso=&page=2&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&start=1&where=web" onclick='goOtherCR(this,"a=pag.pag&r=2&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">2</a>
# <a href="?nso=&page=3&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&start=16&where=web" onclick='goOtherCR(this,"a=pag.pag&r=3&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">3</a>
# <a href="?nso=&page=4&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&start=31&where=web" onclick='goOtherCR(this,"a=pag.pag&r=4&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">4</a>
# <a href="?nso=&page=5&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&start=46&where=web" onclick='goOtherCR(this,"a=pag.pag&r=5&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">5</a>
# <a href="?nso=&page=6&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&start=61&where=web" onclick='goOtherCR(this,"a=pag.pag&r=6&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">6</a>
# <a href="?nso=&page=7&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&start=76&where=web" onclick='goOtherCR(this,"a=pag.pag&r=7&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">7</a>
# <a href="?nso=&page=8&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&start=91&where=web" onclick='goOtherCR(this,"a=pag.pag&r=8&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">8</a>
# <a href="?nso=&page=9&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&start=106&where=web" onclick='goOtherCR(this,"a=pag.pag&r=9&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">9</a>
# <a href="?nso=&page=10&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&start=121&where=web" onclick='goOtherCR(this,"a=pag.pag&r=10&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">10</a></div><a href="?nso=&page=11&qdt=-1&query=%EC%B6%95%EA%B5%AC&qvt=-1&sm=tab_pag&start=1&where=web" onclick='goOtherCR(this,"a=pag.pag&r=11&i=&u="+urlencode(this.href))' role="button" class="btn_next" aria-disabled="false"><i class="spnew ico_page_arr">다음</i></a></div></div></div><div id="sub_pack" class="sub_pack"><section class="sc_new sp_nkeyword" id="nx_right_related_keywords"> <div class="api_subject_bx _related_box"> <div class="api_title_area"> <h2 class="api_title">연관 검색어<a href="https://help.naver.com/alias/search/word/word_1.naver" class="api_link_help" onclick="return goOtherCR(this, 'a=rsk_top.guide&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" target="_blank"><i class="spnew api_ico_help">도움말</i></a></h2> <div class="api_title_sub"> <a href="https://help.naver.com/support/alias/search/word/word_2.naver" class="btn_report" onclick="return goOtherCR(this, 'a=rsk_top.report&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" target="_blank"><span class="txt">신고</span></a><a href="#" onclick="return tCR('a=rsk_top.1fold&amp;r=1&amp;i=');" class="btn_close _close"><i class="spnew api_ico_close4">검색어제안 기능 닫기</i></a> </div> </div> <div class="related_srch"> <ul class="lst_related_srch _list_box"> <li class="item"> <a class="keyword" href="?where=nexearch&amp;query=%EC%B6%95%EA%B5%AC+%EA%B5%AD%EA%B0%80%EB%8C%80%ED%91%9C+%ED%8F%89%EA%B0%80%EC%A0%84&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=1&amp;u=' + urlencode(this.href))"> <div class="tit">축구 국가대표 평가전</div> </a> </li> <li class="item"> <a class="keyword" href="?where=nexearch&amp;query=%EC%B6%95%EA%B5%AC+u20&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=2&amp;u=' + urlencode(this.href))"> <div class="tit">축구 u20</div> </a> </li> <li class="item"> <a class="keyword" href="?where=nexearch&amp;query=%EC%B6%95%EA%B5%AC+%EA%B5%AD%EA%B0%80%EB%8C%80%ED%91%9C+%EC%9D%BC%EC%A0%95&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=3&amp;u=' + urlencode(this.href))"> <div class="tit">축구 국가대표 일정</div> </a> </li> <li class="item"> <a class="keyword" href="?where=nexearch&amp;query=%ED%95%9C%EC%9D%BC%EC%A0%84+%EC%B6%95%EA%B5%AC&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=4&amp;u=' + urlencode(this.href))"> <div class="tit">한일전 축구</div> </a> </li> <li class="item"> <a class="keyword" href="?where=nexearch&amp;query=%EC%B6%95%EA%B5%AC+u17&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=5&amp;u=' + urlencode(this.href))"> <div class="tit">축구 u17</div> </a> </li> <li class="item"> <a class="keyword" href="?where=nexearch&amp;query=%EC%B6%95%EA%B5%AC+%ED%95%9C%EC%9D%BC%EC%A0%84&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=6&amp;u=' + urlencode(this.href))"> <div class="tit">축구 한일전</div> </a> </li> <li class="item"> <a class="keyword" href="?where=nexearch&amp;query=%EC%98%A4%EB%8A%98+%EC%B6%95%EA%B5%AC&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=7&amp;u=' + urlencode(this.href))"> <div class="tit">오늘 축구</div> </a> </li> <li class="item"> <a class="keyword" href="?where=nexearch&amp;query=%EC%B6%95%EA%B5%AC+u17+%EC%A4%91%EA%B3%84&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=8&amp;u=' + urlencode(this.href))"> <div class="tit">축구 u17 중계</div> </a> </li> <li class="item"> <a class="keyword" href="?where=nexearch&amp;query=%EC%B6%95%EA%B5%AC+%EA%B2%B0%EC%8A%B9&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0" onclick="return goOtherCR(this, 'a=rsk_top*q.list1&amp;r=9&amp;u=' + urlencode(this. ...

# %%
# fake-useragent : useragent 생성
# 파이썬으로 크롤링 시 상대 서버는 파이썬 프로그램으로 요청이 들어온다는 걸 알게 됨
# 요청을 브라우저로 하고 있다고 속여내는 방법

# %%
from fake_useragent import UserAgent

userAgent = UserAgent()

print(userAgent.ie)
print(userAgent.chrome)
print(userAgent.random)
# Out:
# Mozilla/5.0 (compatible; MSIE 6.0; Windows NT 5.1; SV1; .NET CLR 2.0.50727)
# Mozilla/5.0 (Windows; U; Windows NT 5.2; en-US) AppleWebKit/534.10 (KHTML, like Gecko) Chrome/7.0.540.0 Safari/534.10
# Mozilla/5.0 (X11; U; Linux i686; en-US) AppleWebKit/532.0 (KHTML, like Gecko) Chrome/3.0.196.0 Safari/532.0

# %%
from fake_useragent import UserAgent
import urllib.request as req
import json
import csv

kosdaq=[]

try: 
    userAgent = UserAgent()

    url = "https://finance.daum.net/api/search/ranks?limit=10"

    headers = {
        "user-agent" : userAgent.random,
        "referer" : "https://finance.daum.net/"
    }

    request_url = req.Request(url,headers=headers)
    # request_url = req.Request(url)
    info = req.urlopen(request_url)
    res = info.read().decode("utf-8")
except Exception as e:
    print(e)
else:
    # print(res)
    data = json.loads(res)["data"]

    for item in data:
        print("순위 : {}, 금액: {}, 회사명: {}".format(item["rank"],item["tradePrice"],item["name"]))

        kosdaq.append(item)

        with open("./finance.csv","w",newline="")as f:
            output = csv.writer(f)
            # 헤더명 작성
            output.writerow(kosdaq[0].keys())

            for row in kosdaq:
                output.writerow(row.values())
# Out:
# 순위 : 1, 금액: 50000, 회사명: 카카오
# 순위 : 2, 금액: 70100, 회사명: 삼성전자
# 순위 : 3, 금액: 80900, 회사명: 금양
# 순위 : 4, 금액: 954000, 회사명: 에코프로
# 순위 : 5, 금액: 87100, 회사명: 삼성중공우
# 순위 : 6, 금액: 3680, 회사명: 삼부토건
# 순위 : 7, 금액: 28850, 회사명: KODEX 2차전지산업
# 순위 : 8, 금액: 17270, 회사명: 두산에너빌리티
# 순위 : 9, 금액: 31190, 회사명: KODEX 반도체
# 순위 : 10, 금액: 6250, 회사명: 시큐센
